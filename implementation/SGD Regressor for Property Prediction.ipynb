# %% [markdown]
# Title: SGD Regressor for Property Prediction
# =======
# - Created: 2019.10.03
# - Updated: 2019.11.06
# - Author: Kyung Min, Lee
#
# Learned from
# - "Chapter 2 of Hands-on Machine Learning Book"
# - Sckit-Learn documents

# %% [markdown]
# ## SGD stands for Stochastic Gradient Descent: the gradient of the loss is estimated each sample at a time and the model is updated along the way with a decreasing strength schedule (aka learning rate).
#
# > class sklearn.linear_model.SGDRegressor(loss=’squared_loss’, penalty=’l2’, alpha=0.0001, l1_ratio=0.15, fit_intercept=True, max_iter=1000, tol=0.001, shuffle=True, verbose=0, epsilon=0.1, random_state=None, learning_rate=’invscaling’, eta0=0.01, power_t=0.25, early_stopping=False, validation_fraction=0.1, n_iter_no_change=5, warm_start=False, average=False)[source]

# %% [markdown]
# HyperParameters
# ---

# %% [markdown]
# -   **loss**:  : str, default: ‘squared_loss’
#   - The loss function to be used. The possible values are *‘squared_loss’, ‘huber’, ‘epsilon_insensitive’, or ‘squared_epsilon_insensitive’*
#     - *‘squared_loss’* refers to the ordinary least squares fit(DEFAULT)
#     -  *‘huber’* modifies ‘squared_loss’ to focus less on getting outliers correct by switching from squared to linear loss past a distance of epsilon.
#     -  *‘epsilon_insensitive’* ignores errors less than epsilon and is linear past that; this is the loss function used in SVR.
#     - *‘squared_epsilon_insensitive’* is the same but becomes squared loss past a tolerance of epsilon.
#
#
# - **penalty**:  str, ‘none’, ‘l2’, ‘l1’, or ‘elasticnet’
#   - The penalty (aka regularization term) to be used.
#     - *l2*(DEFAULT): standard regularizer for linear SVM models. => <U>Lidge Regression</U>
#     $$ min(||Y-\widehat{Y}||^2_2 + \lambda||\theta||^2_2$$
#       - $\lambda$: ridge function의 alpha값, alpha값이 클 수록 penalty도 커지면서 계수의 크기가 줄어든다. 이는 변수를 축소하면서 다중공선선(multicollinearity)를 방지하는데 쓰임
#       - 모든 변수를 가지고 오면서 계수값을 줄인다. 하지만 model이 아직까지도 복잡한 상태이고 변수도 유지하므로 모델 성능 저하에 영향을 미칠 수 있다.
#
#     - *l1*: Regularization with l1 norm, 중요한 몇 개의 변수만 선택하고 다른 계수들은 0으로 줄인다. 이 특징은 Feature selection으로 알려져 있고 ridge regression은 이 과정이 없다 => <U>Lasso Regression</U>
#       - 변수를 자동채택 할 수 있어 일반적으로 많은 변수를 다룰 때 활용
#     $$ min(||Y-\widehat{Y}||^2_2 + \lambda||\theta||^2_1$$
#       - 변수들 끼리 상관관계가 존재한다면 Lasso는 단 한개의 변수만 채택하므로 정보의 손실을 야기하여 정확성이 떨어질 수 있다.
#
#     - *elasticnet*: Ridge & Lasso regression의 조합=> <U>Elastic Net</U>
#       $$ min(||Y-\widehat{Y}||^2_2 + \lambda_1||\theta||^2_1+ \lambda_2||\theta||^2_2$$
#       - 상관 관계가 존재하는 변수로 구성된 그룹을 형성한다. 이 그룹의 변수 중 하나가 강력한 예측변수가 있다면 이 그룹을 model building에 포함시킨다. 상관관계를 최대한 유지하면서 필요없는 변수의 영향을 최대한 지우는 것
#
#       $ Alpha = \lambda_1 + \lambda_2 $    and       l1_ratio$  = \frac{\lambda_1 }{\lambda_1 + \lambda_2} $
#
#
# - **alpha**[float]: Constant that multiplies the regularization term. Defaults to 0.0001 Also used to compute learning_rate when set to ‘optimal’.  &nbsp;
#
# - **1l_ratio**[float]: The Elastic Net mixing parameter, with 0 <= l1_ratio <= 1. l1_ratio=0 corresponds to L2 penalty, l1_ratio=1 to L1. Defaults to 0.15.
#
# - **fit_intercept**[bool]: Whether the intercept should be estimated or not. If False, the data is assumed to be already centered. Defaults to True.
#
# - **max_iter**[int, optional](defalut=1000): The maximum number of passes over the training data (aka epochs). It only impacts the behavior in the fit method, and not the partial_fit.
#
# - **tol**[ float or None, optional (default=1e-3)]: The stopping criterion. If it is not None, the iterations will stop when (loss > best_loss - tol) for n_iter_no_change consecutive epochs.
#
# - **shuffle**[bool, optional]: Whether or not the training data should be shuffled after each epoch. Defaults to True.
#
# - **epsilon**[float]: Epsilon in the epsilon-insensitive loss functions; only if loss is ‘huber’, ‘epsilon_insensitive’, or ‘squared_epsilon_insensitive’.
#   - For ‘huber’, determines the threshold at which it becomes less important to get the prediction exactly right. For epsilon-insensitive, any differences between the current prediction and the correct label are ignored if they are less than this threshold.
#
# - **random_state**[int, RandomState instance or None, optional (default=None)]: The seed of the pseudo random number generator to use when shuffling the data.
#   -  If None, the random number generator is the RandomState instance used by np.random.
#
# - **learning_rate**[string, optional]: learning rate schedule
#   - *constant*: eta = eta0
#   - *optimal*: $ eta = \frac{1.0}{alpha * ( t + t0)}$, t0 is chose by  a heuristic proposed by Leon Bottou
#   - *invscaling*[default]: $eta = \frac{eta0}{pow(t, 'power_t')}
#   - *adaptive*: eta = eta0, as long as the training keeps decreasing.
#     -  Each time n_iter_no_change consecutive epochs fail to decrease the training loss by tol or fail to increase validation score by tol if early_stopping is True, the current learning rate is divided by 5.
#
# - **eta0**[double]: The initial learning rate for the ‘constant’, ‘invscaling’ or ‘adaptive’ schedules. The default value is 0.01.
#
# - **power_t**[double]: The exponent for inverse scaling learning rate [default 0.5].
#
# - **early_stopping**[bool, default=False]: Whether to use early stopping to terminate training when validation score is not improving.
#   - If set to True, it will automatically set aside a fraction of training data as validation and terminate training when validation score is not improving by at least tol for n_iter_no_change consecutive epochs.
#
# - **validation_fraction**[float, default=0.1]: The proportion of training data to set aside as validation set for early stopping.
#   - Must be between 0 and 1. Only used if early_stopping is True.
#
# - **n_iter_no_change**[int, default=5]: Number of iterations with no improvement to wait before early stopping.
#
# - **warm_start**[bool, optional]: When set to True, reuse the solution of the previous call to fit as initialization, otherwise, just erase the previous solution.
#   - Repeatedly calling fit or partial_fit when warm_start is True can result in a different solution than when calling fit a single time because of the way the data is shuffled. If a dynamic learning rate is used, the learning rate is adapted depending on the number of samples already seen. Calling fit resets this counter, while partial_fit will result in increasing the existing counter.
#
# - **average**[bool or int, optional]: When set to True, computes the averaged SGD weights and stores the result in the coef_ attribute.
#   -  If set to an int greater than 1, averaging will begin once the total number of samples seen reaches average. So average=10 will begin averaging after seeing 10 samples.

# %% [markdown]
# Attributes
# ---

# %% [markdown]
# - **coef_** [array, shape (n_features,)]:  Weights assigned to the features.
#
# - **intercept_**[array, shape (1,)]: The intercept term.
#
# - **average_coef_**[array, shape (n_features,)]: Averaged weights assigned to the features.
#
# - **average_intercept_ **[array, shape (1,)]: The averaged intercept term.
#
# - **n_iter_**[int]: The actual number of iterations to reach the stopping criterion.

# %% [markdown]
# Regularization
# ---

# %% [markdown]
# - regression의 결과 중 상관계수가 높은 것들에 집중하는 penalty를 주는 방법
# -

# %% [markdown]
# Setup
# ---

# %%
# Python ≥3.5 is required
import sys
assert sys.version_info >= (3, 5)

# Scikit-Learn ≥0.20 is required
import sklearn

# Pandas
import pandas as pd

# Common imports
import numpy as np
import os

# to make this notebook's output stable across runs
np.random.seed(42)

# To plot pretty figures
# %matplotlib inline
import matplotlib as mpl
import matplotlib.pyplot as plt
mpl.rc('axes', labelsize=14)
mpl.rc('xtick', labelsize=12)
mpl.rc('ytick', labelsize=12)

# Where to save the figures
"""
PROJECT_ROOT_DIR = "."
CHAPTER_ID = "end_to_end_project"
IMAGES_PATH = os.path.join(PROJECT_ROOT_DIR, "images", CHAPTER_ID)
os.makedirs(IMAGES_PATH, exist_ok=True)
"""

def save_fig(fig_id, tight_layout=True, fig_extension="png", resolution=300):
    path = os.path.join(IMAGES_PATH, fig_id + "." + fig_extension)
    print("Saving figure", fig_id)
    if tight_layout:
        plt.tight_layout()
    plt.savefig(path, format=fig_extension, dpi=resolution)

# Ignore useless warnings (see SciPy issue #5998)
import warnings
warnings.filterwarnings(action="ignore", message="^internal gelsd")

# %% [markdown]
# Get the data
# ============

# %%
from google.colab import files
uploaded=files.upload()

for fn in uploaded.keys():
  print('User uploaded file"{name}" with length{length} bytes'.format(
      name = fn, length=len(uploaded[fn])
  ))
# Out:
#      <input type="file" id="files-1e70dc91-2b69-4370-a2a9-59a4fe44da72" name="files[]" multiple disabled />
#      <output id="result-1e70dc91-2b69-4370-a2a9-59a4fe44da72">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving 3MA_data.csv to 3MA_data (1).csv
# User uploaded file"3MA_data.csv" with length30235 bytes

# %%
from google.colab import drive

drive.mount('/content/gdrive')

# %%
import pandas as pd

df = pd.read_csv("3MA_data.csv")
df.head()
# Out:
#    yield stress  elongation  1k_voltage     1k_RE     1k_IM  UTS(no)  \
# 0    193.928416    0.000000    2.247535  7.353994 -0.617027    412.0
# 1    193.928416    7.832161    2.249186  7.330924 -0.934697    412.0
# 2    193.928416    7.825444    2.248753  7.367316 -0.574723    412.0
# 3    193.928416    7.813692    2.249833  7.345533 -0.862965    412.0
# 4    193.928416    7.780144    2.247326  7.350974 -0.681030    412.0
#
#       5k_RE     5k_IM  5k_time  5k_voltage
# 0  8.103753  0.048710      0.0    5.330770
# 1  8.084683  0.057399      3.2    5.329357
# 2  8.099559  0.125401      6.4    5.331381
# 3  8.103011  0.153286      9.6    5.329095
# 4  8.122078  0.185302     12.8    5.333564

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 209 entries, 0 to 208
# Data columns (total 10 columns):
# yield stress    203 non-null float64
# elongation      204 non-null float64
# 1k_voltage      209 non-null float64
# 1k_RE           209 non-null float64
# 1k_IM           209 non-null float64
# UTS(no)         204 non-null float64
# 5k_RE           190 non-null float64
# 5k_IM           190 non-null float64
# 5k_time         190 non-null float64
# 5k_voltage      190 non-null float64
# dtypes: float64(10)
# memory usage: 16.5 KB

# %% [markdown]
# 2 Variable (1k_RE & 1k_IM) data
# ---

# %%
df = df.loc[:,["yield stress", "elongation", "1k_RE", "1k_IM"]]
df = df.drop(df.index[190:209])
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 190 entries, 0 to 189
# Data columns (total 4 columns):
# yield stress    190 non-null float64
# elongation      190 non-null float64
# 1k_RE           190 non-null float64
# 1k_IM           190 non-null float64
# dtypes: float64(4)
# memory usage: 7.4 KB

# %%
df.describe()
# Out:
#        yield stress  elongation       1k_RE       1k_IM
# count    190.000000  190.000000  190.000000  190.000000
# mean     331.194462    5.071727    7.184671   -0.994367
# std       60.202631    1.598025    0.078204    0.122292
# min      193.928416    0.000000    7.076378   -1.220670
# 25%      294.251701    3.747314    7.121649   -1.065305
# 50%      346.269052    5.080847    7.162842   -1.015719
# 75%      380.555745    6.401437    7.245272   -0.922856
# max      406.890446    7.832161    7.367316   -0.574723

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
df.hist(bins=50, figsize=(20,15))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x000001643C35EF60>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001644D88BB38>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x000001644D8BF048>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001644D8E45C0>]],
#       dtype=object)

# %%
# to make this notebook's output identical at every run
np.random.seed(42)

# %%
# train, test data split
from sklearn.model_selection import train_test_split

X = df.loc[:,["1k_RE","1k_IM"]]
ys = df.loc[:,"yield stress"]
elong = df.loc[:,"elongation"]

X_train, X_test, ys_train, ys_test = train_test_split(X, ys, test_size=0.2, random_state=42)
X_train, X_test, el_train, el_test = train_test_split(X, elong, test_size=0.2, random_state=42)
len(X_train)
# Out:
# 152

# %%
len(X_test)
# Out:
# 39

# %% [markdown]
# ## 6 Variables (1k_RE, 1k_IM, 1k_voltage, 5k_RE, 5k_IM, 5k_voltage) data

# %%
df = pd.read_csv("3MA_data.csv")
df = df.drop(df.index[190:209])
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 190 entries, 0 to 189
# Data columns (total 10 columns):
# yield stress    190 non-null float64
# elongation      190 non-null float64
# 1k_voltage      190 non-null float64
# 1k_RE           190 non-null float64
# 1k_IM           190 non-null float64
# UTS(no)         190 non-null float64
# 5k_RE           190 non-null float64
# 5k_IM           190 non-null float64
# 5k_time         190 non-null float64
# 5k_voltage      190 non-null float64
# dtypes: float64(10)
# memory usage: 16.3 KB

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
df.hist(bins=50, figsize=(20,15))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x000002C35FE24CC0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000002C35F1D5EF0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000002C35F413940>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x000002C360032470>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000002C3600399E8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000002C360041F28>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x000002C3600514A8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000002C35F5EEA58>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000002C35F5EEA90>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x000002C35F62D518>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000002C35F64EA90>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000002C35F67E048>]],
#       dtype=object)

# %%
# to make this notebook's output identical at every run
np.random.seed(42)

# %%
# train, test data split
from sklearn.model_selection import train_test_split

X = df.loc[:,["1k_RE","1k_IM", "1k_voltage", "5k_RE", "5k_IM", "5k_voltage"]]
ys = df.loc[:,"yield stress"]
elong = df.loc[:,"elongation"]

X_train, X_test, ys_train, ys_test = train_test_split(X, ys, test_size=0.2, random_state=42)
X_train, X_test, el_train, el_test = train_test_split(X, elong, test_size=0.2, random_state=42)
len(X_train)
# Out:
# 152

# %%
len(X_test)
# Out:
# 38

# %%
#X_train.to_csv("X_train.csv", mode='w')

# %% [markdown]
# Discover and visualize the data to gain insights
# ===

# %%
# Copy the dataset in order not to harm train set
df_copy = df.copy()
df_copy.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 209 entries, 0 to 208
# Data columns (total 10 columns):
# yield stress    203 non-null float64
# elongation      204 non-null float64
# 1k_voltage      209 non-null float64
# 1k_RE           209 non-null float64
# 1k_IM           209 non-null float64
# UTS(no)         204 non-null float64
# 5k_RE           190 non-null float64
# 5k_IM           190 non-null float64
# 5k_time         190 non-null float64
# 5k_voltage      190 non-null float64
# dtypes: float64(10)
# memory usage: 16.4 KB

# %%
X_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 152 entries, 51 to 102
# Data columns (total 6 columns):
# 1k_RE         152 non-null float64
# 1k_IM         152 non-null float64
# 1k_voltage    152 non-null float64
# 5k_RE         152 non-null float64
# 5k_IM         152 non-null float64
# 5k_voltage    152 non-null float64
# dtypes: float64(6)
# memory usage: 8.3 KB

# %%
df_copy.plot(kind="scatter", x="1k_RE", y="yield stress")

# %%
df_copy.plot(kind="scatter", x="1k_IM", y="yield stress")

# %%
# Analysis of Standard correlation coefficient
corr_matrix = df_copy.corr()
corr_matrix
# Out:
#               yield stress  elongation     1k_RE     1k_IM
# yield stress      1.000000   -0.776652 -0.947305 -0.726706
# elongation       -0.776652    1.000000  0.883247  0.591942
# 1k_RE            -0.947305    0.883247  1.000000  0.816920
# 1k_IM            -0.726706    0.591942  0.816920  1.000000

# %%
# Check what affects the most for the yield stress
corr_matrix["yield stress"].sort_values(ascending=False)

# 1kHz_voltage > 1k_RE > 1k_IM
# Out:
# yield stress    1.000000
# 1k_IM          -0.726706
# elongation     -0.776652
# 1k_RE          -0.947305
# Name: yield stress, dtype: float64

# %%
corr_matrix["elongation"].sort_values(ascending=False)
# Out:
# elongation      1.000000
# 1k_RE           0.883247
# 1k_IM           0.591942
# yield stress   -0.776652
# Name: elongation, dtype: float64

# %% [markdown]
# ## PCA & ICA Feature Extraction

# %%
import pandas as pd

df = pd.read_csv("3MA_data.csv")
df = df.drop(df.index[190:209])
df.head()
# Out:
#    yield stress  elongation  1k_voltage     1k_RE     1k_IM  UTS(no)  \
# 0    193.928416    0.000000    2.247535  7.353994 -0.617027    412.0
# 1    193.928416    7.832161    2.249186  7.330924 -0.934697    412.0
# 2    193.928416    7.825444    2.248753  7.367316 -0.574723    412.0
# 3    193.928416    7.813692    2.249833  7.345533 -0.862965    412.0
# 4    193.928416    7.780144    2.247326  7.350974 -0.681030    412.0
#
#       5k_RE     5k_IM  5k_time  5k_voltage
# 0  8.103753  0.048710      0.0    5.330770
# 1  8.084683  0.057399      3.2    5.329357
# 2  8.099559  0.125401      6.4    5.331381
# 3  8.103011  0.153286      9.6    5.329095
# 4  8.122078  0.185302     12.8    5.333564

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 190 entries, 0 to 189
# Data columns (total 10 columns):
# yield stress    190 non-null float64
# elongation      190 non-null float64
# 1k_voltage      190 non-null float64
# 1k_RE           190 non-null float64
# 1k_IM           190 non-null float64
# UTS(no)         190 non-null float64
# 5k_RE           190 non-null float64
# 5k_IM           190 non-null float64
# 5k_time         190 non-null float64
# 5k_voltage      190 non-null float64
# dtypes: float64(10)
# memory usage: 16.3 KB

# %%
df = df.loc[:,["1k_RE","yield stress"]]#, "yield stress", "elongation"]]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 190 entries, 0 to 189
# Data columns (total 2 columns):
# 1k_RE           190 non-null float64
# yield stress    190 non-null float64
# dtypes: float64(2)
# memory usage: 4.5 KB

# %%
x = df.loc[:,["1k_RE"]]
y = df.loc[:,["yield stress"]]

plt.scatter(x,y)

# %%
from sklearn.decomposition import PCA
pca = PCA()
S_pca_ = pca.fit(df).transform(df)

S_pca_
#plt.scatter(x,y)
plt.plot(S_pca_)
plt.show()

# %%
S_pca_
# Out:
# array([[ 1.37266150e+02,  5.50642606e-03],
#        [ 1.37266121e+02,  2.85756754e-02],
#        [ 1.37266167e+02, -7.81650013e-03],
#        [ 1.37266140e+02,  1.39674512e-02],
#        [ 1.37266147e+02,  8.52613461e-03],
#        [-4.17237927e+01, -4.62482987e-03],
#        [-4.24076410e+01,  6.78786054e-03],
#        [-4.30458327e+01,  1.43598034e-02],
#        [-4.36976526e+01, -1.13802212e-02],
#        [-4.44247884e+01, -4.41951975e-03],
#        [-4.50254228e+01, -5.38082805e-04],
#        [-4.57230067e+01, -3.70448965e-03],
#        [-4.63244758e+01,  1.25007796e-03],
#        [-4.69551493e+01,  2.20210204e-03],
#        [-4.76324356e+01, -1.27200231e-02],
#        [-4.82714933e+01,  3.28867776e-02],
#        [-4.88934672e+01, -1.09460136e-03],
#        [-4.95172627e+01, -9.34246653e-03],
#        [-5.01671116e+01, -5.34858762e-04],
#        [-5.08015426e+01,  2.72459272e-02],
#        [-5.14419182e+01,  1.71301454e-02],
#        [-5.20380816e+01,  2.66910062e-02],
#        [-5.26768764e+01,  1.27542956e-02],
#        [-5.32595885e+01,  2.46487477e-02],
#        [-5.38972097e+01,  2.25897944e-02],
#        [-5.44897263e+01,  1.49822602e-02],
#        [-5.51061102e+01, -1.81010730e-04],
#        [-5.56989804e+01,  2.71773570e-02],
#        [-5.63375172e+01,  1.06989710e-02],
#        [-5.68992023e+01,  1.95638147e-02],
#        [-5.74745346e+01,  7.90011284e-04],
#        [-5.80778957e+01,  2.04786570e-02],
#        [-5.87130418e+01, -1.55225083e-02],
#        [-5.92571234e+01,  2.11568148e-02],
#        [-5.98246319e+01, -1.07916977e-02],
#        [-6.03905229e+01,  2.02230133e-02],
#        [-6.09939776e+01, -2.79187575e-03],
#        [-6.15840721e+01,  3.81492949e-03],
#        [-6.21298104e+01, -9.89862749e-03],
#        [-6.27195704e+01, -8.80427266e-03],
#        [-6.32533083e+01, -2.27676455e-02],
#        [-6.37705732e+01,  5.90431631e-03],
#        [-6.43362362e+01, -1.03134724e-03],
#        [-6.48412131e+01, -2.51973293e-05],
#        [-6.54533795e+01, -8.95216766e-03],
#        [-6.59804862e+01,  7.90433644e-03],
#        [-6.65559158e+01,  5.18180409e-03],
#        [-6.70826651e+01, -1.42805690e-02],
#        [-6.76256205e+01, -2.81997706e-02],
#        [-6.81050528e+01, -2.30536568e-03],
#        [-6.86843772e+01, -1.04186689e-02],
#        [-6.91982682e+01,  2.51320918e-03],
#        [-6.96934515e+01,  1.95273806e-02],
#        [-7.02211974e+01, -4.96600587e-03],
#        [-7.07424727e+01,  7.90801214e-03],
#        [-7.12677906e+01, -3.95161077e-03],
#        [-7.17557430e+01,  1.59148807e-02],
#        [-7.22207185e+01, -2.00282025e-02],
#        [-7.27969088e+01,  1.27590961e-02],
#        [-7.32343375e+01, -1.23013662e-02],
#        [-7.37542504e+01, -8.33880099e-04],
#        [-7.42137491e+01,  6.83357856e-03],
#        [-7.47351735e+01, -1.34310471e-02],
#        [-7.51564144e+01, -2.03600561e-02],
#        [-7.56960104e+01, -2.76703917e-02]])

# %%
from sklearn.decomposition import FastICA

ica = FastICA()
S_ica_ = ica.fit(df).transform(df)

S_ica_
#plt.scatter(x,y)
plt.plot(S_ica_)
plt.ylim(-5,5)
plt.show()

# %%
S_ica_
# Out:
# array([[ 0.12465819, -0.11245105],
#        [ 0.06501892, -0.20384373],
#        [ 0.159101  , -0.05967006],
#        [ 0.10278451, -0.14597081],
#        [ 0.11685156, -0.12441413],
#        [ 0.10018125, -0.14996011],
#        [ 0.13573511, -0.09547651],
#        [ 0.06378073, -0.20574115],
#        [ 0.07015555, -0.18696144],
#        [ 0.07788784, -0.16613213],
#        [ 0.07150407, -0.16723568],
#        [ 0.08374892, -0.14006332],
#        [ 0.06277635, -0.1639987 ],
#        [ 0.06721688, -0.1493226 ],
#        [ 0.04880672, -0.1697322 ],
#        [ 0.09534364, -0.09111951],
#        [ 0.07494506, -0.11521885],
#        [ 0.10037568, -0.06942855],
#        [ 0.07542715, -0.10098819],
#        [ 0.10680013, -0.04648163],
#        [ 0.11559475, -0.02666244],
#        [ 0.09706338, -0.04904699],
#        [ 0.10295561, -0.03419171],
#        [ 0.09062949, -0.04738169],
#        [ 0.13354407,  0.02389069],
#        [ 0.05724072, -0.087574  ],
#        [ 0.16373039,  0.08087903],
#        [ 0.10015868, -0.01145507],
#        [ 0.09367426, -0.01626224],
#        [ 0.08487365, -0.02492187],
#        [ 0.08737539, -0.01633112],
#        [ 0.04300199, -0.07971985],
#        [ 0.09101705, -0.00144949],
#        [ 0.03883445, -0.07693883],
#        [ 0.07783071, -0.01286675],
#        [ 0.10418041,  0.03185023],
#        [ 0.10196469,  0.03265429],
#        [ 0.12706427,  0.07520412],
#        [ 0.11349542,  0.0584544 ],
#        [ 0.13794733,  0.09989563],
#        [ 0.06471797, -0.00848056],
#        [ 0.07010201,  0.00360503],
#        [ 0.01992902, -0.06961663],
#        [ 0.06713404,  0.00643062],
#        [ 0.10462485,  0.06748048],
#        [ 0.09286564,  0.05297212],
#        [ 0.12180575,  0.10073839],
#        [ 0.0697822 ,  0.0244223 ],
#        [ 0.03746806, -0.02174783],
#        [ 0.03284638, -0.02554997],
#        [ 0.05884631,  0.01753554],
#        [ 0.08508001,  0.06090164],
#        [ 0.08952359,  0.07081155],
#        [ 0.09109419,  0.07628195],
#        [ 0.05989377,  0.03150243],
#        [ 0.09074281,  0.08175388],
#        [ 0.02034524, -0.02322171],
#        [ 0.03015449, -0.00521984],
#        [ 0.06865934,  0.05661157],
#        [ 0.0620332 ,  0.04929435],
#        [ 0.10086297,  0.11152806],
#        [ 0.0581527 ,  0.04882021],
#        [ 0.06455505,  0.06125243],
#        [-0.02845388, -0.07866287],
#        [ 0.0185824 , -0.00410972],
#        [ 0.07836733,  0.09009039],
#        [ 0.01600138, -0.0030719 ],
#        [ 0.09999927,  0.12814635],
#        [ 0.01030143, -0.0068379 ],
#        [ 0.02061388,  0.01129297],
#        [-0.01044493, -0.03392024],
#        [ 0.00070502, -0.01451386],
#        [ 0.05252265,  0.06718134],
#        [ 0.02384121,  0.02561602],
#        [ 0.07608448,  0.10786523],
#        [ 0.02701038,  0.03490893],
#        [ 0.08989845,  0.13345531],
#        [-0.05428636, -0.08531488],
#        [-0.02587119, -0.03947168],
#        [-0.06797214, -0.10197855],
#        [-0.02154386, -0.02868472],
#        [-0.03439007, -0.04627399],
#        [ 0.00600751,  0.01777779],
#        [-0.01182898, -0.00758558],
#        [ 0.00960261,  0.02742014],
#        [-0.03455395, -0.03825402],
#        [ 0.03639834,  0.07253742],
#        [ 0.01894919,  0.04776801],
#        [-0.0343622 , -0.03188214],
#        [-0.03314158, -0.02813202],
#        [-0.01135456,  0.00726186],
#        [-0.04028132, -0.03509659],
#        [-0.0241213 , -0.00847489],
#        [-0.06561834, -0.07013955],
#        [-0.02158274, -0.00065178],
#        [ 0.00181317,  0.03701298],
#        [-0.04166004, -0.02782444],
#        [-0.01728666,  0.01137447],
#        [-0.04817421, -0.03401754],
#        [-0.00581391,  0.03263375],
#        [-0.09519151, -0.10258893],
#        [-0.01823305,  0.01719032],
#        [-0.0952568 , -0.09910674],
#        [-0.0299479 ,  0.00288534],
#        [-0.09136687, -0.08947046],
#        [-0.03256844,  0.00232511],
#        [-0.08284702, -0.07312119],
#        [-0.02597487,  0.01573509],
#        [-0.12773192, -0.13834284],
#        [-0.03490792,  0.00556947],
#        [-0.03136822,  0.01267547],
#        [-0.01519531,  0.03915072],
#        [ 0.01954407,  0.09393531],
#        [-0.03846841,  0.00671345],
#        [-0.04173578,  0.0033047 ],
#        [-0.03998271,  0.00768026],
#        [-0.02493684,  0.03221362],
#        [-0.03642035,  0.01629654],
#        [-0.00925751,  0.05957179],
#        [-0.08049355, -0.04795407],
#        [-0.05656939, -0.00970984],
#        [-0.08829735, -0.05691104],
#        [-0.02332704,  0.04431063],
#        [-0.03993565,  0.02031098],
#        [-0.03350836,  0.03172304],
#        [-0.05112396,  0.00640969],
#        [ 0.01714401,  0.11247141],
#        [-0.04000235,  0.02640169],
#        [-0.03694341,  0.03250869],
#        [-0.05454548,  0.00718809],
#        [-0.03026223,  0.04587213],
#        [-0.06045858,  0.00111039],
#        [-0.08067953, -0.02846573],
#        [-0.01479527,  0.07393808],
#        [-0.03352602,  0.04684222],
#        [-0.04416817,  0.03186186],
#        [-0.03668814,  0.04486672],
#        [-0.05010543,  0.02563552],
#        [-0.05320478,  0.02228035],
#        [-0.01531301,  0.08184405],
#        [-0.13386358, -0.09841295],
#        [-0.04664335,  0.03662066],
#        [-0.02595193,  0.06970784],
#        [-0.04937915,  0.03524413],
#        [-0.12184074, -0.07439519],
#        [-0.09633712, -0.03389699],
#        [-0.12165735, -0.0713803 ],
#        [-0.08627415, -0.01574589],
#        [-0.11761363, -0.06248299],
#        [-0.11293595, -0.05390509],
#        [-0.09386829, -0.02337533],
#        [-0.05529149,  0.0371035 ],
#        [-0.12661898, -0.07088978],
#        [-0.08466471, -0.00518627],
#        [-0.10815069, -0.03993495],
#        [-0.0601983 ,  0.0348205 ],
#        [-0.11170844, -0.04278097],
#        [-0.01927993,  0.10026306],
#        [-0.11465484, -0.04468896],
#        [-0.03263491,  0.08225514],
#        [-0.11338758, -0.04024117],
#        [-0.05449948,  0.05133462],
#        [-0.07217666,  0.0255503 ],
#        [-0.03727621,  0.0802392 ],
#        [-0.04070212,  0.07629314],
#        [-0.0051437 ,  0.13196381],
#        [-0.07979062,  0.01871658],
#        [-0.06243273,  0.04656688],
#        [-0.06554482,  0.04291428],
#        [-0.043086  ,  0.07868418],
#        [-0.08719724,  0.01225237],
#        [-0.08074113,  0.02341809],
#        [-0.03095947,  0.10086935],
#        [ 0.00447543,  0.1563711 ],
#        [-0.0629526 ,  0.05410265],
#        [-0.04256406,  0.08662739],
#        [-0.07651589,  0.03573491],
#        [-0.12100244, -0.03134261],
#        [-0.05821548,  0.06604051],
#        [-0.09202519,  0.01538213],
#        [-0.06189692,  0.06271288],
#        [-0.11375005, -0.01566936],
#        [-0.0212995 ,  0.1270322 ],
#        [-0.10664514, -0.00247971],
#        [-0.04230077,  0.09709033],
#        [-0.0724729 ,  0.05200327],
#        [-0.09275997,  0.02193075],
#        [-0.04089892,  0.10255675],
#        [-0.02341209,  0.13028532],
#        [-0.00505921,  0.15960274]])

# %%
pca.get_params()
# Out:
# {'copy': True,
#  'iterated_power': 'auto',
#  'n_components': None,
#  'random_state': None,
#  'svd_solver': 'auto',
#  'tol': 0.0,
#  'whiten': False}

# %%
component = pd.DataFrame(pca.components_)

component.to_csv("component.csv", mode ='w')

# %%
print("ica shape: ",S_ica_.shape)
print("pca shape: ",S_pca_.shape)
# Out:
# ica shape:  (190, 6)
# pca shape:  (190, 6)

# %%
S_pca_
# Out:
# array([[ 4.13343458e-01,  3.42362030e-02, -4.36755487e-02,
#          1.95685619e-02, -8.29013795e-03, -1.95543048e-03],
#        [ 1.31306621e-01,  3.32139463e-03,  1.01152609e-01,
#         -1.77782340e-04, -1.20153050e-02,  1.32363806e-03],
#        [ 4.60541940e-01, -3.92864363e-02, -5.79754925e-02,
#          1.42919078e-02, -8.86714345e-03, -4.86974812e-04],
#        ...,
#        [-1.00061144e-01, -1.33069607e-02, -3.84008921e-02,
#          1.67999696e-02,  1.09781773e-03,  1.86047274e-03],
#        [ 2.12633829e-02, -2.58169690e-01, -1.07641950e-01,
#          5.96649085e-03, -2.77767539e-03,  4.54493721e-04],
#        [-5.74014759e-02, -2.10771152e-02, -5.18398375e-02,
#         -1.90972018e-03, -2.51447884e-03,  5.38466955e-03]])

# %%
S_ica_ = pd.DataFrame(S_ica_)
#S_ica_.to_csv("ICA_data_in.csv", mode ='w')

S_pca_ = pd.DataFrame(S_pca_)
#S_pca_.to_csv("PCA_data_in.csv", mode ='w')

# %%
S_pca_.components_
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-73-64258e3b1e6a> in <module>
# ----> 1 S_pca_.components_
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5065             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5066                 return self[name]
# -> 5067             return object.__getattribute__(self, name)
#    5068
#    5069     def __setattr__(self, name, value):
#
# AttributeError: 'DataFrame' object has no attribute 'components_'

# %%
S_ica_.hist(bins=50, figsize=(20,15))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x0000020A64D2B9B0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000020A64E25D68>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x0000020A64FF7198>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000020A6501D710>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x0000020A657C5C88>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000020A657F5208>]],
#       dtype=object)

# %%
S_pca_ = pd.DataFrame(S_pca_)
S_pca_.hist(bins=50, figsize=(20,15))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x0000020A64D0D4A8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000020A6504C940>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x0000020A649E9CF8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000020A6506B3C8>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x0000020A64FC4D30>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000020A661E9D30>]],
#       dtype=object)

# %%
# Check that there exist no corelations between the dataset
S_pca_ = pd.DataFrame(S_pca_)
corr_matrix = S_pca_.corr()
corr_matrix
# Out:
#               0             1             2             3             4  \
# 0  1.000000e+00  1.008066e-13  8.821474e-16  4.908003e-14  3.004090e-15
# 1  1.008066e-13  1.000000e+00  4.118656e-15  2.147130e-15 -2.197531e-15
# 2  8.821474e-16  4.118656e-15  1.000000e+00  1.513182e-15 -1.174707e-15
# 3  4.908003e-14  2.147130e-15  1.513182e-15  1.000000e+00  2.242931e-15
# 4  3.004090e-15 -2.197531e-15 -1.174707e-15  2.242931e-15  1.000000e+00
# 5  5.846117e-14 -3.879673e-15 -1.127039e-16  8.607457e-16 -2.860699e-15
# 6 -4.039789e-15 -1.423048e-15 -3.602926e-15  1.570853e-15  9.706812e-16
# 7  2.098993e-14 -1.223000e-14  3.856278e-15 -1.225416e-14  4.708953e-15
#
#               5             6             7
# 0  5.846117e-14 -4.039789e-15  2.098993e-14
# 1 -3.879673e-15 -1.423048e-15 -1.223000e-14
# 2 -1.127039e-16 -3.602926e-15  3.856278e-15
# 3  8.607457e-16  1.570853e-15 -1.225416e-14
# 4 -2.860699e-15  9.706812e-16  4.708953e-15
# 5  1.000000e+00  1.919634e-16  1.359624e-14
# 6  1.919634e-16  1.000000e+00 -1.648703e-14
# 7  1.359624e-14 -1.648703e-14  1.000000e+00

# %%
x = np.linspace(0,189)
plt.plot(x, S_pca_[:,1])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-24-f1e53c4df098> in <module>
#       1 x = np.linspace(0,189)
# ----> 2 plt.plot(x, S_pca_[:,1])
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    2925             if self.columns.nlevels > 1:
#    2926                 return self._getitem_multilevel(key)
# -> 2927             indexer = self.columns.get_loc(key)
#    2928             if is_integer(indexer):
#    2929                 indexer = [indexer]
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2655                                  'backfill or nearest lookups')
#    2656             try:
# -> 2657                 return self._engine.get_loc(key)
#    2658             except KeyError:
#    2659                 return self._engine.get_loc(self._maybe_cast_indexer(key))
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# TypeError: '(slice(None, None, None), 1)' is an invalid key

# %% [markdown]
# ## Choose ICA & PCA data and add

# %%
#df = pd.read_csv("3MA_data_in+ica+pca.csv")
df = pd.read_csv("3MA_data_in+ica+pca.csv")
df = df.drop(df.index[190:209])
df.info()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-67-821d3040e623> in <module>
#       1 #df = pd.read_csv("3MA_data_in+ica+pca.csv")
# ----> 2 df = pd.read_csv("3MA_data_in+ica+pca.csv")
#       3 df = df.drop(df.index[190:209])
#       4 df.info()
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\io\parsers.py in parser_f(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, dialect, tupleize_cols, error_bad_lines, warn_bad_lines, delim_whitespace, low_memory, memory_map, float_precision)
#     700                     skip_blank_lines=skip_blank_lines)
#     701
# --> 702         return _read(filepath_or_buffer, kwds)
#     703
#     704     parser_f.__name__ = name
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\io\parsers.py in _read(filepath_or_buffer, kwds)
#     427
#     428     # Create the parser.
# --> 429     parser = TextFileReader(filepath_or_buffer, **kwds)
#     430
#     431     if chunksize or iterator:
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\io\parsers.py in __init__(self, f, engine, **kwds)
#     893             self.options['has_index_names'] = kwds['has_index_names']
#     894
# --> 895         self._make_engine(self.engine)
#     896
#     897     def close(self):
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\io\parsers.py in _make_engine(self, engine)
#    1120     def _make_engine(self, engine='c'):
#    1121         if engine == 'c':
# -> 1122             self._engine = CParserWrapper(self.f, **self.options)
#    1123         else:
#    1124             if engine == 'python':
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\io\parsers.py in __init__(self, src, **kwds)
#    1851         kwds['usecols'] = self.usecols
#    1852
# -> 1853         self._reader = parsers.TextReader(src, **kwds)
#    1854         self.unnamed_cols = self._reader.unnamed_cols
#    1855
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader.__cinit__()
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader._setup_parser_source()
#
# FileNotFoundError: [Errno 2] File b'3MA_data_in+ica+pca.csv' does not exist: b'3MA_data_in+ica+pca.csv'

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
df.hist(bins=50, figsize=(20,15))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x0000020A6DE1B3C8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000020A6DECD128>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000020A6DDD0588>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000020A6DE5BB00>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000020A6D5D60B8>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x0000020A6D5FA630>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000020A6D622BA8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000020A6D655198>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000020A6D6551D0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000020A6D6A1C50>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x0000020A6D6D1208>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000020A6D6F8780>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000020A6D720CF8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000020A6D7522B0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000020A6D778828>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x0000020A6D79EDA0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000020A6D7CE358>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000020A6D7F58D0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000020A6D81FE48>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000020A6D84E400>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x0000020A6D873978>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000020A6D89EEF0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000020A6D8CD4A8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000020A6D8F5A20>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000020A6D91DF98>]],
#       dtype=object)

# %%
corr_matrix = df.corr()
corr_matrix
# Out:
#               yield stress    elongation  1k_voltage     1k_RE     1k_IM  \
# yield stress  1.000000e+00 -8.868064e-01   -0.994657 -0.980480 -0.732689
# elongation   -8.868064e-01  1.000000e+00    0.897797  0.883247  0.591942
# 1k_voltage   -9.946571e-01  8.977971e-01    1.000000  0.987401  0.736476
# 1k_RE        -9.804797e-01  8.832472e-01    0.987401  1.000000  0.816920
# 1k_IM        -7.326889e-01  5.919424e-01    0.736476  0.816920  1.000000
# 5k_RE        -4.418234e-01  2.900375e-01    0.421207  0.405007  0.310078
# 5k_IM        -8.254805e-02  5.342175e-02    0.079463  0.075760  0.035729
# 5k_RE        -5.675711e-02  8.356727e-01 -2.275866e-01  2.971368e-02
# 5k_IM         1.613902e-01 -4.304058e-04  3.782342e-04  3.153543e-06
# 5k_voltage   -1.334726e-02  3.017754e-01  8.730485e-03 -5.847513e-01
# ica_1        -7.702900e-03  3.581994e-01 -6.742130e-01 -5.809886e-01
# ica_2         5.581943e-02  2.917827e-01  4.896977e-01 -4.557039e-01
# ica_3         9.625184e-01 -8.959037e-02  5.903727e-02 -6.617188e-02
# ica_4        -1.787590e-02 -1.832224e-01 -3.679923e-01  1.558676e-01
# ica_5         4.564779e-02  1.086559e-01 -6.632677e-02 -1.009906e-02
# ica_6         2.482407e-01 -1.114613e-02 -3.822312e-01  1.934176e-01
# ica_7        -2.539028e-03 -1.745287e-01 -1.256728e-01  3.557816e-01
# ica_8        -7.968687e-02 -8.381936e-01 -2.087229e-02 -5.118788e-01
# pca_1        -4.439391e-10  2.254753e-09  5.148682e-08  8.149666e-08
# pca_2        -2.242050e-10  6.145459e-10 -7.410398e-09 -5.802037e-08
# pca_3        -6.097330e-10  3.536493e-09 -2.144921e-08 -3.184387e-08
# pca_4         1.000000e+00  9.334010e-10  1.837725e-08  4.434542e-08
# pca_5         9.334010e-10  1.000000e+00  2.943244e-08 -1.510031e-08
# pca_6         1.837725e-08  2.943244e-08  1.000000e+00 -9.539407e-08
# pca_7         4.434542e-08 -1.510031e-08 -9.539407e-08  1.000000e+00
# pca_8         4.358432e-08 -8.939968e-08 -4.582635e-07 -5.149875e-07
# pca_9         5.317218e-03  1.863556e-01  1.522030e-01 -3.586207e-01
#
#                      pca_8     pca_9
# yield stress  5.576266e-07  0.000449
# elongation   -2.791007e-07 -0.140301
# 1k_voltage   -6.238348e-02 -0.029553
# 1k_RE         3.126290e-03 -0.034292
# 1k_IM        -2.378025e-04  0.035020
# 5k_RE        -1.701122e-03  0.179308
# 5k_IM        -7.635947e-06  0.076930
# 5k_voltage    2.280566e-02  0.415280
# ica_1        -1.784503e-01  0.214665
# ica_2         2.848107e-01  0.405039
# ica_3        -2.339233e-01 -0.012054
# ica_4        -2.031498e-01 -0.279602
# ica_5         3.251907e-01 -0.009094
# ica_6         8.085199e-01 -0.015723
# ica_7        -1.026956e-01  0.071765
# ica_8         1.450814e-01  0.056899
# pca_1        -5.615824e-07 -0.000536
# pca_2         2.551052e-08  0.302784
# pca_3        -1.169641e-07 -0.064119
# pca_4         4.358432e-08  0.005317
# pca_5        -8.939968e-08  0.186356
# pca_6        -4.582635e-07  0.152203
# pca_7        -5.149875e-07 -0.358621
# pca_8         1.000000e+00  0.121889
# pca_9         1.218889e-01  1.000000
#
# [25 rows x 25 columns]

# %% [markdown]
# - -1.0과 -0.7 사이이면, 강한 음적 선형관계
# - -0.7과 -0.3 사이이면, 뚜렷한 음적 선형관계
# - -0.3과 -0.1 사이이면, 약한 음적 선형관계
# - -0.1과 +0.1 사이이면, 거의 무시될 수 있는 선형관계
# - +0.1과 +0.3 사이이면, 약한 양적 선형관계
# - +0.3과 +0.7 사이이면, 뚜렷한 양적 선형관계
# - +0.7과 +1.0 사이이면, 강한 양적 선형관계

# %%
abs_corr_matrix = np.abs(corr_matrix)

# %%
import seaborn as sns  

plt.figure(figsize=(15,15))
sns.heatmap(data = abs_corr_matrix, annot=True, 
fmt = '.2f', linewidths=.5, cmap='Greens')

save_fig("abs_heatmap_out.png")
# Out:
# Saving figure abs_heatmap_out.png

# %%
# Check what affects the most for the yield stress
yield_corr = corr_matrix["yield stress"].sort_values(ascending=False)

for key in yield_corr.keys():
    print(key, ":", yield_corr[key])
# Out:
# yield stress : 1.0
# ica_1 : 0.06962788286614387
# ica_8 : 0.04379273920916437
# ica_3 : 0.02405453050468304
# pca_9 : 0.0004491579620978134
# pca_4 : 2.9354875462543234e-06
# pca_8 : 5.576266175357538e-07
# pca_3 : 2.0970752589978376e-07
# pca_5 : -1.84413639934652e-08
# pca_7 : -8.942899701493162e-08
# pca_6 : -1.9742402428936778e-07
# pca_2 : -0.0002882989379111304
# ica_6 : -0.008504869705678235
# ica_5 : -0.008975958531794876
# 5k_IM : -0.08254804673206297
# ica_7 : -0.1837622198721719
# 5k_RE : -0.441823369925482
# ica_2 : -0.5624680807385593
# 5k_voltage : -0.5811107067374501
# 1k_IM : -0.7326888502982527
# ica_4 : -0.8014759744089266
# elongation : -0.8868063653609044
# 1k_RE : -0.980479669847717
# 1k_voltage : -0.9946570634639302
# pca_1 : -0.9999999584374989

# %%
elong_corr = corr_matrix["elongation"].sort_values(ascending=False)
elong_corr
# Out:
# elongation      1.000000e+00
# 1k_voltage      8.977971e-01
# pca_1           8.869396e-01
# 1k_RE           8.832472e-01
# ica_4           8.704528e-01
# 1k_IM           5.919424e-01
# ica_2           3.905889e-01
# 5k_voltage      2.944989e-01
# 5k_RE           2.900375e-01
# 5k_IM           5.342175e-02
# ica_6           1.744662e-02
# ica_5           1.210702e-02
# pca_4           1.075673e-03
# pca_5           4.347234e-05
# pca_6           2.720386e-05
# pca_8          -2.791007e-07
# pca_7          -4.515735e-06
# pca_3          -9.851583e-05
# ica_3          -1.787726e-02
# ica_8          -6.689147e-02
# pca_9          -1.403011e-01
# ica_1          -1.563417e-01
# ica_7          -2.450807e-01
# pca_2          -4.618842e-01
# yield stress   -8.868064e-01
# Name: elongation, dtype: float64

# %% [markdown]
# # 10 variables
# #### feature discarded: pca_3 ~ pca_8, ica_3, ica_5~ ica_8, 5k_IM

# %%
df = pd.DataFrame(df)
df
# Out:
#              0         1         2         3         4         5         6   \
# 0    193.928416  0.000001  2.247535  7.353994 -0.617027  8.103753  0.048710
# 1    193.928416  7.832161  2.249186  7.330924 -0.934697  8.084683  0.057399
# 2    193.928416  7.825444  2.248753  7.367316 -0.574723  8.099559  0.125401
# 3    193.928416  7.813692  2.249833  7.345533 -0.862965  8.103011  0.153286
# 4    193.928416  7.780144  2.247326  7.350974 -0.681030  8.122078  0.185302
# 5    193.928416  7.742729  2.248745  7.344526 -0.815595  8.103104  0.089639
# 6    193.928416  7.705922  2.250206  7.358278 -0.740627  8.084127  0.123405
# 166  -0.008047  0.397802 -0.520768 -0.612701 -0.459489 -0.142210 -0.018301
# 167   0.551912  0.798227  0.031032  1.351203  0.100781 -0.581423 -0.684461
# 168   0.131523 -0.195162  0.230460  1.045507 -0.064666 -0.401416 -0.184716
# 169   0.076035  0.444866  0.965033  0.172782 -0.046699 -0.029387 -0.111919
# 170  -0.295007 -1.224749  0.331267  1.103823  0.457651 -0.527781  0.319159
# 171   0.627413 -0.418105 -0.013225  0.034002  0.466200 -1.106652 -0.796987
# 172  -0.348580 -0.953486  0.934002  0.452797 -1.410516  0.156238  0.380065
# 173  -0.192582 -0.777106  1.699558 -0.478455 -1.862810  1.186011  0.197557
# 174   0.255416  0.301377  0.238796 -0.150875 -0.279340 -0.462568 -0.342848
# 175   0.289947 -0.934339  0.962487 -0.202102 -0.473702 -0.576499 -0.388923
# 176   0.558288 -1.120417  0.262914  0.397815  0.286549 -0.935602 -0.732380
# 177   0.112255 -1.120316 -1.460791  0.298204 -0.553670 -1.685948 -0.201716
# 178  -0.395685 -1.599569  1.047684 -0.953603 -0.491122 -1.203400  0.419914
# 179   0.209280 -0.701889 -0.742286  0.446403 -0.747901 -0.470758 -0.310187
# 180   0.145571  0.945547 -0.115494 -0.753139 -1.075432 -0.462832 -0.223491
# 181   0.409103 -0.285597 -0.957129  0.142349  0.082546 -1.596975 -0.551845
# 182   0.166970  0.268318  1.107639  0.859038 -1.295479  0.687315 -0.264728
# 183  -0.166085  0.182900 -0.908522 -0.375932 -0.622033 -0.540881  0.128967
# 184   0.909772  0.400387  0.581497  0.862960 -0.544972 -0.249471 -1.155262
# 185   0.810141  1.292746 -0.198534 -2.391419 -0.379395 -1.110941 -1.034209
# 186   0.439550 -0.041533 -0.392786 -1.877592 -0.295632 -1.051999 -0.597313
# 187   0.800474 -0.140165  0.389409  1.560220 -1.178133 -0.131090 -1.030405
# 188  -0.102707 -2.402913  2.426449  0.254092 -0.382208 -0.864356  0.028892
# 189   0.406597 -0.069889  0.947352 -0.308984 -2.498036  0.993733 -0.575524
#
# [190 rows x 25 columns]

# %%
# train, test data split
from sklearn.model_selection import train_test_split

X = df.loc[:,["1k_RE","1k_IM", "1k_voltage", "5k_RE", "5k_voltage", "pca_1", "ica_2","ica_4"]]
ys = df.loc[:,"yield stress"]
elong = df.loc[:,"elongation"]

X_train, X_test, ys_train, ys_test = train_test_split(X, ys, test_size=0.2)
X_train, X_test, el_train, el_test = train_test_split(X, elong, test_size=0.2)
len(X_train)
# Out:
# 152

# %%
len(X_test)
# Out:
# 38

# %%
X_train.shape
# Out:
# (152, 8)

# %%
X_train
# Out:
#         1k_RE     1k_IM  1k_voltage     5k_RE  5k_voltage       pca_1  \
# 6    7.358278 -0.740627    2.250206  8.084127    5.327734  137.290372
# 90   7.170437 -1.045207    2.195374  8.058109    5.308463  -11.147900
# 104  7.129160 -1.201569    2.190503  8.072862    5.306379  -22.860009
# 80   7.174609 -0.998405    2.200066  8.070097    5.310379   -1.947439
# 178  7.100199 -1.030840    2.175598  8.065609    5.316091  -70.256702
# 55     305.276137
# 5      193.928416
# 45     290.786577
# 28     258.910963
# 64     316.455684
# 62     314.154595
# 43     287.570781
# 78     331.273142
# 48     295.387732
# 150    385.684125
# 3      193.928416
# 184    404.428756
# 76     329.246265
# 4      193.928416
# 63     315.336853
# 46     292.332441
# 27     256.590764
# 77     330.233242
# 72     325.176236
# 84     336.940957
# 87     339.666074
# 26     254.290912
#           ...
# 125    369.528911
# 146    383.232467
# 128    371.504751
# 86     338.774995
# 53     302.557600
# 173    398.820064
# 1      193.928416
# 169    396.647800
# 80     333.152776
# 185    404.948654
# 100    350.772467
# 178    401.415609
# 130    372.918227
# 129    372.252522
# 38     278.967228
# 11     209.794458
# 51     299.769569
# 188    406.350841
# 112    360.135508
# 179    401.936867
# 95     346.678911
# 159    391.019059
# 117    363.809351
# 58     309.210717
# 151    386.300528
# 171    397.750317
# 50     298.338042
# 164    393.913993
# 61     312.969054
# 136    376.917436
# Name: yield stress, Length: 152, dtype: float64

# %%
# Feature Scaling => Standardization
from sklearn.pipeline import Pipeline
from sklearn.impute import SimpleImputer
from sklearn.preprocessing import StandardScaler

data_pipeline = Pipeline([
    ('imputer', SimpleImputer(strategy="median")),
    ('std_scaler', StandardScaler()),
])
imputer = SimpleImputer(strategy="median")

X_train = imputer.fit_transform(X_train)
X_train_std = data_pipeline.fit_transform(X_train)

ys_train = np.array(ys_train)
ys_train =ys_train.reshape(-1, 1)
ys_train = imputer.fit_transform(ys_train)
ys_train_std = data_pipeline.fit_transform(ys_train)

el_train = np.array(el_train)
el_train =el_train.reshape(-1, 1)
el_train = imputer.fit_transform(el_train)
el_train_std = data_pipeline.fit_transform(el_train)

X_test = imputer.fit_transform(X_test)
X_test_std =data_pipeline.fit_transform(X_test)

ys_test = np.array(ys_test)
ys_test = ys_test.reshape(-1, 1)
ys_test = imputer.fit_transform(ys_test)
ys_test_std = data_pipeline.fit_transform(ys_test)

el_test = np.array(el_test)
el_test = el_test.reshape(-1, 1)
el_test = imputer.fit_transform(el_test)
el_test_std = data_pipeline.fit_transform(el_test)


#print(X_train_std)

ys_test_std
# Out:
# array([[-2.04421426],
#        [-0.79846458],
#        [-0.74158655],
#        [ 1.22400725],
#        [-0.44229709],
#        [ 0.7559952 ],
#        [-1.86540088],
#        [-0.41917952],
#        [ 0.81185702],
#        [ 1.03080267],
#        [ 0.04786108],
#        [ 1.09701079],
#        [ 0.40018939],
#        [ 0.7456588 ],
#        [ 0.56801436],
#        [ 1.02041715],
#        [ 0.18843589],
#        [ 0.86641812],
#        [ 0.90867181],
#        [ 0.38772098],
#        [ 0.65210609],
#        [-0.15830189],
#        [-1.92221054],
#        [-1.08096737],
#        [ 1.00091213],
#        [ 0.09554168],
#        [ 0.98061848],
#        [-0.48807396],
#        [-1.38330395],
#        [-0.10385105],
#        [ 0.73314546],
#        [-2.24107351],
#        [ 0.30450631],
#        [ 0.88767096],
#        [ 0.8008603 ],
#        [-0.88674823],
#        [-1.51307911],
#        [ 0.58033057]])

# %%
#np.savetxt("ys_train.csv", ys_train, delimiter=",")

# %%
X_train_std
# Out:
# array([[ 2.30313758,  2.19610902,  2.26298435, ...,  2.34123565,
#          2.9338945 ,  0.90479238],
#        [-0.14552667, -0.37915428, -0.21587387, ..., -0.16172752,
#         -0.28062532,  0.01897066],
#        [-0.68361221, -1.70121482, -0.43611521, ..., -0.35921686,
#         -0.80968137, -0.05830452],
#        ...,
#        [ 1.67170933,  1.22039411,  1.6406209 , ...,  1.62940683,
#          0.50470727,  1.54395334],
#        [-0.88760524, -0.22536868, -1.07414533, ..., -1.10544308,
#          0.08785671, -1.24385279],
#        [ 1.23013894,  0.86968471,  1.14294807, ...,  1.00134941,
#         -0.47975807,  1.65614969]])

# %%
ys_train
# Out:
# array([[345.859194 ],
#        [342.3491757],
#        [400.8878322],
#        [263.2457198],
#        [296.871402 ],
#        [356.3153804],
#        [366.654355 ],
#        [398.2770909],
#        [305.2761365],
#        [193.928416 ],
#        [290.7865768],
#        [258.9109635],
#        [316.4556836],
#        [314.1545951],
#        [287.5707808],
#        [331.2731424],
#        [295.3877316],
#        [385.6841251],
#        [193.928416 ],
#        [404.4287558],
#        [329.2462646],
#        [193.928416 ],
#        [315.3368533],
#        [292.3324414],
#        [256.5907645],
#        [330.2332422],
#        [325.1762356],
#        [336.9409571],
#        [339.6660743],
#        [254.2909124],
#        [380.087891 ],
#        [344.9516204],
#        [405.4081423],
#        [406.8904463],
#        [261.0940842],
#        [241.7331269],
#        [403.9912956],
#        [328.2624228],
#        [352.3927397],
#        [393.3242347],
#        [227.1339494],
#        [318.7140645],
#        [373.60206  ],
#        [193.928416 ],
#        [402.9501266],
#        [361.6173138],
#        [239.0132519],
#        [217.0652009],
#        [397.1748847],
#        [389.907476 ],
#        [357.1553318],
#        [282.5009981],
#        [311.728646 ],
#        [360.8944233],
#        [271.4283316],
#        [357.9091233],
#        [317.6245466],
#        [377.5188987],
#        [230.2185847],
#        [388.668949 ],
#        [249.4376223],
#        [351.607539 ],
#        [340.591275 ],
#        [363.0492358],
#        [335.9624187],
#        [388.0935933],
#        [273.3904667],
#        [324.1410847],
#        [327.2465236],
#        [358.66976  ],
#        [267.4526422],
#        [405.929592 ],
#        [387.5319199],
#        [236.144673 ],
#        [384.453976 ],
#        [332.1821166],
#        [368.7684819],
#        [233.2364146],
#        [374.2402416],
#        [354.0550831],
#        [198.0040467],
#        [364.5557704],
#        [265.3309169],
#        [275.2899157],
#        [386.8933627],
#        [399.8787968],
#        [293.8730246],
#        [193.928416 ],
#        [394.964976 ],
#        [395.5306474],
#        [310.4938396],
#        [359.4348317],
#        [380.7116965],
#        [193.928416 ],
#        [349.1988703],
#        [284.2355762],
#        [205.9914438],
#        [392.7784793],
#        [353.2571561],
#        [334.1010653],
#        [399.2994626],
#        [370.8627499],
#        [400.3926709],
#        [402.4621999],
#        [341.4414326],
#        [193.928416 ],
#        [344.08029  ],
#        [322.0143481],
#        [368.0616517],
#        [347.4849133],
#        [381.3615336],
#        [378.1495705],
#        [348.3210261],
#        [362.3813123],
#        [320.9614608],
#        [246.945844 ],
#        [277.1383167],
#        [381.9959288],
#        [367.4049917],
#        [319.843856 ],
#        [301.1719203],
#        [394.4477481],
#        [369.5289109],
#        [383.2324675],
#        [371.5047515],
#        [338.774995 ],
#        [302.5575995],
#        [398.8200636],
#        [193.928416 ],
#        [396.6477999],
#        [333.1527757],
#        [404.9486537],
#        [350.7724668],
#        [401.4156088],
#        [372.9182268],
#        [372.2525223],
#        [278.9672283],
#        [209.7944582],
#        [299.7695692],
#        [406.3508414],
#        [360.1355076],
#        [401.9368673],
#        [346.6789108],
#        [391.0190592],
#        [363.8093514],
#        [309.2107175],
#        [386.3005278],
#        [397.7503173],
#        [298.3380418],
#        [393.9139928],
#        [312.9690544],
#        [376.9174364]])

# %% [markdown]
# Select and train a SGD regression model
# ===

# %% [markdown]
# Yield Stress

# %%
# Where to save the figures
PROJECT_ROOT_DIR = "."
CHAPTER_ID = "BestHyperParameter/SGD_Regression/yield_stress_10V_ica&pca"
IMAGES_PATH = os.path.join(PROJECT_ROOT_DIR, "images", CHAPTER_ID)
os.makedirs(IMAGES_PATH, exist_ok=True)

# %%
# Normal Stochastic Gradient Descent

from sklearn.linear_model import SGDRegressor
from sklearn.metrics import mean_squared_error
sgd_reg = SGDRegressor()
sgd_reg.fit(X_train_std, ys_train_std)
ys_predictions_sgd = sgd_reg.predict(X_train_std) * np.std(ys_train) + np.mean(ys_train)
sgd_mse = mean_squared_error(ys_train, ys_predictions_sgd)
sgd_rmse = np.sqrt(sgd_mse)
sgd_rmse
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:724: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# 58.857172465227045

# %% [markdown]
# Hyper Parameters Tuning: GridSearch CV function
# ---

# %% [markdown]
# class sklearn.model_selection.GridSearchCV(estimator, param_grid, scoring=None, n_jobs=None, iid=’warn’, refit=True, cv=’warn’, verbose=0, pre_dispatch=‘2*n_jobs’, error_score=’raise-deprecating’, return_train_score=False)[source]

# %% [markdown]
# GridSearchCV implements a “fit” and a “score” method. It also implements “predict”, “predict_proba”, “decision_function”, “transform” and “inverse_transform” if they are implemented in the estimator used.
#
# The parameters of the estimator used to apply these methods are optimized by cross-validated grid-search over a parameter grid.

# %% [markdown]
# ### parameters
#
# - **estimator**[estimator object.]: This is assumed to implement the scikit-learn estimator interface. Either estimator needs to provide a score function, or scoring must be passed.
#
# - **param_grid**[dict or list of dictionaries]: This enables searching over any sequence of parameter settings.
#   - Dictionary with parameters names (string) as keys and lists of parameter settings to try as values, or a list of such dictionaries, in which case the grids spanned by each dictionary in the list are explored.
#
# - **scoring**[string, callable, list/tuple, dict or None, default: None]: A single string or a callable to evaluate the predictions on the test set.
#   - NOTE that when using custom scorers, each scorer should return a single value. Metric functions returning a list/array of values can be wrapped into multiple scorers that return one value each.
#   - If None, the estimator’s score method is used.
#
# - **n_jobs**[int or None, optional (default=None)]:specify how many concurrent processes/threads should be used for parallelized routines.
#   - None means 1 unless in a joblib.parallel_backend context.
#   - -1 means using all processors.
#   - Whether parallel processing is helpful at improving runtime depends on many factors, and it’s usually a good idea to experiment rather than assuming that increasing the number of jobs is always a good thing. It can be highly detrimental to performance to run multiple copies of some estimators or functions in parallel.
#
# - **pre_dispatch**[int, or string, optional]: Controls the number of jobs that get dispatched during parallel execution
#   - Reducing this number can be useful to avoid an explosion of memory consumption when more jobs get dispatched than CPUs can process.
#     - None, in which case all the jobs are immediately created and spawned. Use this for lightweight and fast-running jobs, to avoid delays due to on-demand spawning of the jobs
#     - An int, giving the exact number of total jobs that are spawned
#     - A string, giving an expression as a function of n_jobs, as in ‘2*n_jobs’
#
# - **iid**[boolean, default=’warn’]: If True, return the average score across folds, weighted by the number of samples in each test set.
#   - In this case, the data is assumed to be identically distributed across the folds, and the loss minimized is the total loss per sample, and not the mean loss across the folds.
#   - If False, return the average score across folds.
#   - Changed in version 0.20: Parameter iid will change from True to False by default in version 0.22, and will be removed in 0.24.
#
# - **cv**[int, cross-validation generator or an iterable, optional]: Determines the cross-validation splitting strategy.
#   - possible inputs of cv are:
#     - None, to use the default 3-fold cross validation,
#     - integer, to specify the number of folds in a (Stratified)KFold,
#     - CV splitter,
#     - An iterable yielding (train, test) splits as arrays of indices.
#     - For integer/None inputs, if the estimator is a classifier and y is either binary or multiclass, StratifiedKFold is used. In all other cases, KFold is used.
#
# - **refit**[ boolean, string, or callable, default=True]: Refit an estimator using the best found parameters on the whole dataset.
#   - For multiple metric evaluation, this needs to be a string denoting the scorer that would be used to find the best parameters for refitting the estimator at the end.
#   - The refitted estimator is made available at the best_estimator_ attribute and permits using predict directly on this GridSearchCV instance.
#   - Also for multiple metric evaluation, the attributes best_index_, best_score_ and best_params_ will only be available if refit is set and all of them will be determined w.r.t this specific scorer. best_score_ is not returned if refit is callable.
#
# - **verbose**[int]: Controls the verbosity: the higher, the more messages.
#
# - **error_score**[‘raise’ or numeric]: Value to assign to the score if an error occurs in estimator fitting.
#   - If set to ‘raise’, the error is raised.
#   - If a numeric value is given, FitFailedWarning is raised.
#   - Default is ‘raise’ but from version 0.22 it will change to np.nan.
#
# - **return_train_score**[boolean, default=False]: If False, the cv_results_ attribute will not include training scores.
#   - Computing training scores is used to get insights on how different parameter settings impact the overfitting/underfitting trade-off.
#   - However computing the scores on the training set can be computationally expensive and is not strictly required to select the parameters that yield the best generalization performance.

# %% [markdown]
# ### Attributes
#
# - **cv_results_**[dict of numpy (masked) ndarrays]: A dict with keys as column headers and values as columns, that can be imported into a pandas DataFrame.
#
# <div>
# {
# 'param_kernel': masked_array(data = ['poly', 'poly', 'rbf', 'rbf'],
#                              mask = [False False False False]...)
#
# 'param_gamma': masked_array(data = [-- -- 0.1 0.2],
#                             mask = [ True  True False False]...),
#
# 'param_degree': masked_array(data = [2.0 3.0 -- --],
#                              mask = [False False  True  True]...),
#
# 'split0_test_score'  : [0.80, 0.70, 0.80, 0.93],
#
# 'split1_test_score'  : [0.82, 0.50, 0.70, 0.78],
#
# 'mean_test_score'    : [0.81, 0.60, 0.75, 0.85],
#
# 'std_test_score'     : [0.01, 0.10, 0.05, 0.08],
#
# 'rank_test_score'    : [2, 4, 3, 1],
#
# 'split0_train_score' : [0.80, 0.92, 0.70, 0.93],
#
# 'split1_train_score' : [0.82, 0.55, 0.70, 0.87],
#
# 'mean_train_score'   : [0.81, 0.74, 0.70, 0.90],
#
# 'std_train_score'    : [0.01, 0.19, 0.00, 0.03],
#
# 'mean_fit_time'      : [0.73, 0.63, 0.43, 0.49],
#
# 'std_fit_time'       : [0.01, 0.02, 0.01, 0.01],
#
# 'mean_score_time'    : [0.01, 0.06, 0.04, 0.04],
#
# 'std_score_time'     : [0.00, 0.00, 0.00, 0.01],
#
# 'params'             : [{'kernel': 'poly', 'degree': 2}, ...],
#
# }
# </div>
#
#   - For multi-metric evaluation, the scores for all the scorers are available in the cv_results_ dict at the keys ending with that scorer’s name ('_<scorer_name>') instead of '_score' shown above.
#
# - **best_estimator**[estimator or dict]: Estimator that was chosen by the search,
#   -  i.e. estimator which gave highest score (or smallest loss if specified) on the left out data. Not available if refit=False.
#
# - **best_score_**[float]:Mean cross-validated score of the best_estimator
#
# - **best_params_**[dict]: Parameter setting that gave the best results on the hold out data.
#
# - **best_index_**[int]: The index (of the cv_results_ arrays) which corresponds to the best candidate parameter setting.
#   - The dict at search.cv_results_['params'][search.best_index_] gives the parameter setting for the best model, that gives the highest mean score (search.best_score_).
#
# - **scorer_**[function or a dict]: Scorer function used on the held out data to choose the best parameters for the model.
#   - For multi-metric evaluation, this attribute holds the validated scoring dict which maps the scorer key to the scorer callable.
#
# - **n_splits_**[int]: The number of cross-validation splits (folds/iterations).
#
# - **refit_time_**[float]: Seconds used for refitting the best model on the whole dataset.
#   - This is present only if refit is not False.

# %%
from sklearn.model_selection import GridSearchCV

param_grid = [
    
    {'penalty': [ 'l2', 'l1', 'elasticnet'], 'alpha': [0.001, 0.01,  0.1],
     'l1_ratio': [0.2,0.4,0.6,0.8], 'learning_rate': ['constant', 'optimal','invscaling','adaptive'],
    'eta0': [0.001, 0.01, 0.1],  'early_stopping':[True]}
  ]

sgd_reg = SGDRegressor()

grid_search = GridSearchCV(sgd_reg, param_grid, cv=2,
                           scoring='neg_mean_squared_error',
                           return_train_score=True)
grid_search.fit(X_train_std, ys_train_std)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:724: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:724: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:724: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:724: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:724: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:724: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:724: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:724: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:724: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:724: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:724: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:724: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:724: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:724: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:724: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:724: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:724: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:724: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:724: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:724: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:724: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:724: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:724: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:724: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:724: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:724: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:724: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:724: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:724: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:724: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:724: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:724: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:724: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:724: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:724: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:724: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:724: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:724: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:724: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:724: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:724: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:724: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:724: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:724: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:724: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:724: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:724: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:724: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:724: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:724: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:724: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:724: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:724: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:724: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:724: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:724: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:724: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:724: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:724: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:724: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:724: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:724: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:724: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:724: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:724: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:724: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:724: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:724: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:724: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:724: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:724: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:724: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:724: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:724: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:724: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:724: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:724: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:724: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:724: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:724: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:724: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:724: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:724: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:724: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:724: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:724: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:724: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:724: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:724: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:724: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:724: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:724: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:724: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:724: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:724: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:724: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:724: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:724: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:724: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:724: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:724: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:724: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:724: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:724: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:724: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:724: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:724: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:724: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:724: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:724: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:724: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:724: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:724: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:724: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:724: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:724: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:724: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:724: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:724: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:724: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:724: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:724: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:724: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:724: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:724: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:724: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:724: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:724: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:724: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:724: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:724: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:724: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:724: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:724: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:724: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:724: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:724: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:724: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:724: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:724: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:724: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:724: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:724: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:724: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:724: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:724: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:724: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:724: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:724: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:724: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:724: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:724: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:724: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:724: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:724: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:724: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:724: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:724: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:724: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:724: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:724: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:724: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:724: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:724: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:724: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:724: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:724: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:724: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:724: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:724: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:724: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:724: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:724: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:724: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:724: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:724: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:724: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:724: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:724: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:724: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:724: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# ...
#   y = column_or_1d(y, warn=True)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:724: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:724: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:724: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:724: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:724: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:724: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:724: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:724: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:724: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:724: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:724: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:724: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:724: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:724: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:724: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:724: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:724: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:724: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:724: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:724: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:724: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:724: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:724: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:724: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:724: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:724: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:724: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:724: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:724: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:724: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:724: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:724: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:724: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:724: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:724: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:724: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:724: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:724: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:724: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:724: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:724: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:724: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:724: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:724: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:724: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:724: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:724: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:724: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:724: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:724: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:724: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:724: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:724: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:724: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:724: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# GridSearchCV(cv=2, error_score='raise-deprecating',
#              estimator=SGDRegressor(alpha=0.0001, average=False,
#                                     early_stopping=False, epsilon=0.1,
#                                     eta0=0.01, fit_intercept=True,
#                                     l1_ratio=0.15, learning_rate='invscaling',
#                                     loss='squared_loss', max_iter=1000,
#                                     n_iter_no_change=5, penalty='l2',
#                                     power_t=0.25, random_state=None,
#                                     shuffle=True, tol=0.001,
#                                     validation_fraction=0.1, ver...
#                                     warm_start=False),
#              iid='warn', n_jobs=None,
#              param_grid=[{'alpha': [0.001, 0.01, 0.1], 'early_stopping': [True],
#                           'eta0': [0.001, 0.01, 0.1],
#                           'l1_ratio': [0.2, 0.4, 0.6, 0.8],
#                           'learning_rate': ['constant', 'optimal', 'invscaling',
#                                             'adaptive'],
#                           'penalty': ['l2', 'l1', 'elasticnet']}],
#              pre_dispatch='2*n_jobs', refit=True, return_train_score=True,
#              scoring='neg_mean_squared_error', verbose=0)

# %%
grid_search.best_estimator_
# Out:
# SGDRegressor(alpha=0.1, average=False, early_stopping=True, epsilon=0.1,
#              eta0=0.001, fit_intercept=True, l1_ratio=0.2,
#              learning_rate='invscaling', loss='squared_loss', max_iter=1000,
#              n_iter_no_change=5, penalty='l1', power_t=0.25, random_state=None,
#              shuffle=True, tol=0.001, validation_fraction=0.1, verbose=0,
#              warm_start=False)

# %%
grid_search.best_params_
# Out:
# {'alpha': 0.1,
#  'early_stopping': True,
#  'eta0': 0.001,
#  'l1_ratio': 0.2,
#  'learning_rate': 'invscaling',
#  'penalty': 'l1'}

# %%
cvres = grid_search.cv_results_
for mean_score, params in zip(cvres["mean_test_score"], cvres["params"]):
    print(np.sqrt(-mean_score), params)
# Out:
# 1.0382974053021006 {'alpha': 0.001, 'early_stopping': True, 'eta0': 0.001, 'l1_ratio': 0.2, 'learning_rate': 'constant', 'penalty': 'l2'}
# 1
{'alpha': 0.1, 'early_stopping': True, 'eta0': 0.001, 'l1_ratio': 0.8, 'learning_rate': 'adaptive', 'penalty': 'l2'}
# 1.0171304339094993 {'alpha': 0.1, 'early_stopping': True, 'eta0': 0.001, 'l1_ratio': 0.8, 'learning_rate': 'adaptive', 'penalty': 'l1'}
# 1.017155443829219 {'alpha': 0.1, 'early_stopping': True, 'eta0': 0.001, 'l1_ratio': 0.8, 'learning_rate': 'adaptive', 'penalty': 'elasticnet'}
# 1.1440336984766633 {'alpha': 0.1, 'early_stopping': True, 'eta0': 0.01, 'l1_ratio': 0.2, 'learning_rate': 'constant', 'penalty': 'l2'}
# 1.0222051717024916 {'alpha': 0.1, 'early_stopping': True, 'eta0': 0.01, 'l1_ratio': 0.2, 'learning_rate': 'constant', 'penalty': 'l1'}
# 1.0551309788826095 {'alpha': 0.1, 'early_stopping': True, 'eta0': 0.01, 'l1_ratio': 0.2, 'learning_rate': 'constant', 'penalty': 'elasticnet'}
# 18100.68345112518 {'alpha': 0.1, 'early_stopping': True, 'eta0': 0.01, 'l1_ratio': 0.2, 'learning_rate': 'optimal', 'penalty': 'l2'}
# 11000805972.745222 {'alpha': 0.1, 'early_stopping': True, 'eta0': 0.01, 'l1_ratio': 0.2, 'learning_rate': 'optimal', 'penalty': 'l1'}
# 4881.252985702491 {'alpha': 0.1, 'early_stopping': True, 'eta0': 0.01, 'l1_ratio': 0.2, 'learning_rate': 'optimal', 'penalty': 'elasticnet'}
# 1.076285818890184 {'alpha': 0.1, 'early_stopping': True, 'eta0': 0.01, 'l1_ratio': 0.2, 'learning_rate': 'invscaling', 'penalty': 'l2'}
# 1.0179327023702607 {'alpha': 0.1, 'early_stopping': True, 'eta0': 0.01, 'l1_ratio': 0.2, 'learning_rate': 'invscaling', 'penalty': 'l1'}
# 1.0628113403223067 {'alpha': 0.1, 'early_stopping': True, 'eta0': 0.01, 'l1_ratio': 0.2, 'learning_rate': 'invscaling', 'penalty': 'elasticnet'}
# 1.0583512974788967 {'alpha': 0.1, 'early_stopping': True, 'eta0': 0.01, 'l1_ratio': 0.2, 'learning_rate': 'adaptive', 'penalty': 'l2'}
# 1.035324152641821 {'alpha': 0.1, 'early_stopping': True, 'eta0': 0.01, 'l1_ratio': 0.2, 'learning_rate': 'adaptive', 'penalty': 'l1'}
# 1.0689453060303225 {'alpha': 0.1, 'early_stopping': True, 'eta0': 0.01, 'l1_ratio': 0.2, 'learning_rate': 'adaptive', 'penalty': 'elasticnet'}
# 1.0468207025457843 {'alpha': 0.1, 'early_stopping': True, 'eta0': 0.01, 'l1_ratio': 0.4, 'learning_rate': 'constant', 'penalty': 'l2'}
# 1.0295410283545603 {'alpha': 0.1, 'early_stopping': True, 'eta0': 0.01, 'l1_ratio': 0.4, 'learning_rate': 'constant', 'penalty': 'l1'}
# 1.0502263971208126 {'alpha': 0.1, 'early_stopping': True, 'eta0': 0.01, 'l1_ratio': 0.4, 'learning_rate': 'constant', 'penalty': 'elasticnet'}
# 73885012.88501273 {'alpha': 0.1, 'early_stopping': True, 'eta0': 0.01, 'l1_ratio': 0.4, 'learning_rate': 'optimal', 'penalty': 'l2'}
# 7038605.259896875 {'alpha': 0.1, 'early_stopping': True, 'eta0': 0.01, 'l1_ratio': 0.4, 'learning_rate': 'optimal', 'penalty': 'l1'}
# 184296.5041517026 {'alpha': 0.1, 'early_stopping': True, 'eta0': 0.01, 'l1_ratio': 0.4, 'learning_rate': 'optimal', 'penalty': 'elasticnet'}
# 1.0634705413579315 {'alpha': 0.1, 'early_stopping': True, 'eta0': 0.01, 'l1_ratio': 0.4, 'learning_rate': 'invscaling', 'penalty': 'l2'}
# 1.021652359753501 {'alpha': 0.1, 'early_stopping': True, 'eta0': 0.01, 'l1_ratio': 0.4, 'learning_rate': 'invscaling', 'penalty': 'l1'}
# 1.0612112273486674 {'alpha': 0.1, 'early_stopping': True, 'eta0': 0.01, 'l1_ratio': 0.4, 'learning_rate': 'invscaling', 'penalty': 'elasticnet'}
# 1.0712817342935779 {'alpha': 0.1, 'early_stopping': True, 'eta0': 0.01, 'l1_ratio': 0.4, 'learning_rate': 'adaptive', 'penalty': 'l2'}
# 1.0278186676684395 {'alpha': 0.1, 'early_stopping': True, 'eta0': 0.01, 'l1_ratio': 0.4, 'learning_rate': 'adaptive', 'penalty': 'l1'}
# 1.0437151154703366 {'alpha': 0.1, 'early_stopping': True, 'eta0': 0.01, 'l1_ratio': 0.4, 'learning_rate': 'adaptive', 'penalty': 'elasticnet'}
# 1.092991435601486 {'alpha': 0.1, 'early_stopping': True, 'eta0': 0.01, 'l1_ratio': 0.6, 'learning_rate': 'constant', 'penalty': 'l2'}
# 1.022820272756508 {'alpha': 0.1, 'early_stopping': True, 'eta0': 0.01, 'l1_ratio': 0.6, 'learning_rate': 'constant', 'penalty': 'l1'}
# 1.0363684411692737 {'alpha': 0.1, 'early_stopping': True, 'eta0': 0.01, 'l1_ratio': 0.6, 'learning_rate': 'constant', 'penalty': 'elasticnet'}
# 76931.05915585559 {'alpha': 0.1, 'early_stopping': True, 'eta0': 0.01, 'l1_ratio': 0.6, 'learning_rate': 'optimal', 'penalty': 'l2'}
# 75947492.62459484 {'alpha': 0.1, 'early_stopping': True, 'eta0': 0.01, 'l1_ratio': 0.6, 'learning_rate': 'optimal', 'penalty': 'l1'}
# 6838474.137711945 {'alpha': 0.1, 'early_stopping': True, 'eta0': 0.01, 'l1_ratio': 0.6, 'learning_rate': 'optimal', 'penalty': 'elasticnet'}
# 1.0690355785888694 {'alpha': 0.1, 'early_stopping': True, 'eta0': 0.01, 'l1_ratio': 0.6, 'learning_rate': 'invscaling', 'penalty': 'l2'}
# 1.0268334773710266 {'alpha': 0.1, 'early_stopping': True, 'eta0': 0.01, 'l1_ratio': 0.6, 'learning_rate': 'invscaling', 'penalty': 'l1'}
# 1.0312064080199195 {'alpha': 0.1, 'early_stopping': True, 'eta0': 0.01, 'l1_ratio': 0.6, 'learning_rate': 'invscaling', 'penalty': 'elasticnet'}
# 1.058286121560808 {'alpha': 0.1, 'early_stopping': True, 'eta0': 0.01, 'l1_ratio': 0.6, 'learning_rate': 'adaptive', 'penalty': 'l2'}
# 1.0353336199592367 {'alpha': 0.1, 'early_stopping': True, 'eta0': 0.01, 'l1_ratio': 0.6, 'learning_rate': 'adaptive', 'penalty': 'l1'}
# 1.0397626854238085 {'alpha': 0.1, 'early_stopping': True, 'eta0': 0.01, 'l1_ratio': 0.6, 'learning_rate': 'adaptive', 'penalty': 'elasticnet'}
# 1.060399585617935 {'alpha': 0.1, 'early_stopping': True, 'eta0': 0.01, 'l1_ratio': 0.8, 'learning_rate': 'constant', 'penalty': 'l2'}
# 1.0396124834738092 {'alpha': 0.1, 'early_stopping': True, 'eta0': 0.01, 'l1_ratio': 0.8, 'learning_rate': 'constant', 'penalty': 'l1'}
# 1.0356935547628705 {'alpha': 0.1, 'early_stopping': True, 'eta0': 0.01, 'l1_ratio': 0.8, 'learning_rate': 'constant', 'penalty': 'elasticnet'}
# 2719822.444063241 {'alpha': 0.1, 'early_stopping': True, 'eta0': 0.01, 'l1_ratio': 0.8, 'learning_rate': 'optimal', 'penalty': 'l2'}
# 1146416412.05385 {'alpha': 0.1, 'early_stopping': True, 'eta0': 0.01, 'l1_ratio': 0.8, 'learning_rate': 'optimal', 'penalty': 'l1'}
# 6034797.631332654 {'alpha': 0.1, 'early_stopping': True, 'eta0': 0.01, 'l1_ratio': 0.8, 'learning_rate': 'optimal', 'penalty': 'elasticnet'}
# 1.0590980537632022 {'alpha': 0.1, 'early_stopping': True, 'eta0': 0.01, 'l1_ratio': 0.8, 'learning_rate': 'invscaling', 'penalty': 'l2'}
# 1.0192611350475933 {'alpha': 0.1, 'early_stopping': True, 'eta0': 0.01, 'l1_ratio': 0.8, 'learning_rate': 'invscaling', 'penalty': 'l1'}
# 1.0285326530952934 {'alpha': 0.1, 'early_stopping': True, 'eta0': 0.01, 'l1_ratio': 0.8, 'learning_rate': 'invscaling', 'penalty': 'elasticnet'}
# 1.050895513553586 {'alpha': 0.1, 'early_stopping': True, 'eta0': 0.01, 'l1_ratio': 0.8, 'learning_rate': 'adaptive', 'penalty': 'l2'}
# 1.034844865006902 {'alpha': 0.1, 'early_stopping': True, 'eta0': 0.01, 'l1_ratio': 0.8, 'learning_rate': 'adaptive', 'penalty': 'l1'}
# 1.0472555619022283 {'alpha': 0.1, 'early_stopping': True, 'eta0': 0.01, 'l1_ratio': 0.8, 'learning_rate': 'adaptive', 'penalty': 'elasticnet'}
# 2.247165135255777 {'alpha': 0.1, 'early_stopping': True, 'eta0': 0.1, 'l1_ratio': 0.2, 'learning_rate': 'constant', 'penalty': 'l2'}
# 1.1100381478566077 {'alpha': 0.1, 'early_stopping': True, 'eta0': 0.1, 'l1_ratio': 0.2, 'learning_rate': 'constant', 'penalty': 'l1'}
# 1.173008710044437 {'alpha': 0.1, 'early_stopping': True, 'eta0': 0.1, 'l1_ratio': 0.2, 'learning_rate': 'constant', 'penalty': 'elasticnet'}
# 237083.0823516989 {'alpha': 0.1, 'early_stopping': True, 'eta0': 0.1, 'l1_ratio': 0.2, 'learning_rate': 'optimal', 'penalty': 'l2'}
# 2967542.4785556733 {'alpha': 0.1, 'early_stopping': True, 'eta0': 0.1, 'l1_ratio': 0.2, 'learning_rate': 'optimal', 'penalty': 'l1'}
# 25625980.727125827 {'alpha': 0.1, 'early_stopping': True, 'eta0': 0.1, 'l1_ratio': 0.2, 'learning_rate': 'optimal', 'penalty': 'elasticnet'}
# 1.0778151699196805 {'alpha': 0.1, 'early_stopping': True, 'eta0': 0.1, 'l1_ratio': 0.2, 'learning_rate': 'invscaling', 'penalty': 'l2'}
# 1.0309564490773027 {'alpha': 0.1, 'early_stopping': True, 'eta0': 0.1, 'l1_ratio': 0.2, 'learning_rate': 'invscaling', 'penalty': 'l1'}
# 1.0442761891891388 {'alpha': 0.1, 'early_stopping': True, 'eta0': 0.1, 'l1_ratio': 0.2, 'learning_rate': 'invscaling', 'penalty': 'elasticnet'}
# 1.0644477462394732 {'alpha': 0.1, 'early_stopping': True, 'eta0': 0.1, 'l1_ratio': 0.2, 'learning_rate': 'adaptive', 'penalty': 'l2'}
# 1.0387698838745314 {'alpha': 0.1, 'early_stopping': True, 'eta0': 0.1, 'l1_ratio': 0.2, 'learning_rate': 'adaptive', 'penalty': 'l1'}
# 1.0734006797345614 {'alpha': 0.1, 'early_stopping': True, 'eta0': 0.1, 'l1_ratio': 0.2, 'learning_rate': 'adaptive', 'penalty': 'elasticnet'}
# 1.3166072116848153 {'alpha': 0.1, 'early_stopping': True, 'eta0': 0.1, 'l1_ratio': 0.4, 'learning_rate': 'constant', 'penalty': 'l2'}
# 1.137587980202043 {'alpha': 0.1, 'early_stopping': True, 'eta0': 0.1, 'l1_ratio': 0.4, 'learning_rate': 'constant', 'penalty': 'l1'}
# 1.081825762072468 {'alpha': 0.1, 'early_stopping': True, 'eta0': 0.1, 'l1_ratio': 0.4, 'learning_rate': 'constant', 'penalty': 'elasticnet'}
# 29357114.662054833 {'alpha': 0.1, 'early_stopping': True, 'eta0': 0.1, 'l1_ratio': 0.4, 'learning_rate': 'optimal', 'penalty': 'l2'}
# 1227144.8560345448 {'alpha': 0.1, 'early_stopping': True, 'eta0': 0.1, 'l1_ratio': 0.4, 'learning_rate': 'optimal', 'penalty': 'l1'}
# 115180580.48903453 {'alpha': 0.1, 'early_stopping': True, 'eta0': 0.1, 'l1_ratio': 0.4, 'learning_rate': 'optimal', 'penalty': 'elasticnet'}
# 1.11647884562924 {'alpha': 0.1, 'early_stopping': True, 'eta0': 0.1, 'l1_ratio': 0.4, 'learning_rate': 'invscaling', 'penalty': 'l2'}
# 1.0175040464951237 {'alpha': 0.1, 'early_stopping': True, 'eta0': 0.1, 'l1_ratio': 0.4, 'learning_rate': 'invscaling', 'penalty': 'l1'}
# 1.0648654209798976 {'alpha': 0.1, 'early_stopping': True, 'eta0': 0.1, 'l1_ratio': 0.4, 'learning_rate': 'invscaling', 'penalty': 'elasticnet'}
# 1.058404354066446 {'alpha': 0.1, 'early_stopping': True, 'eta0': 0.1, 'l1_ratio': 0.4, 'learning_rate': 'adaptive', 'penalty': 'l2'}
# 1.0392158767146946 {'alpha': 0.1, 'early_stopping': True, 'eta0': 0.1, 'l1_ratio': 0.4, 'learning_rate': 'adaptive', 'penalty': 'l1'}
# 1.0670606808644119 {'alpha': 0.1, 'early_stopping': True, 'eta0': 0.1, 'l1_ratio': 0.4, 'learning_rate': 'adaptive', 'penalty': 'elasticnet'}
# 2.687245413965945 {'alpha': 0.1, 'early_stopping': True, 'eta0': 0.1, 'l1_ratio': 0.6, 'learning_rate': 'constant', 'penalty': 'l2'}
# 1.0381899518569446 {'alpha': 0.1, 'early_stopping': True, 'eta0': 0.1, 'l1_ratio': 0.6, 'learning_rate': 'constant', 'penalty': 'l1'}
# 1.015132250654298 {'alpha': 0.1, 'early_stopping': True, 'eta0': 0.1, 'l1_ratio': 0.6, 'learning_rate': 'constant', 'penalty': 'elasticnet'}
# 9588343.280018272 {'alpha': 0.1, 'early_stopping': True, 'eta0': 0.1, 'l1_ratio': 0.6, 'learning_rate': 'optimal', 'penalty': 'l2'}
# 7843111.814396461 {'alpha': 0.1, 'early_stopping': True, 'eta0': 0.1, 'l1_ratio': 0.6, 'learning_rate': 'optimal', 'penalty': 'l1'}
# 181.34110621159525 {'alpha': 0.1, 'early_stopping': True, 'eta0': 0.1, 'l1_ratio': 0.6, 'learning_rate': 'optimal', 'penalty': 'elasticnet'}
# 1.0730996915514075 {'alpha': 0.1, 'early_stopping': True, 'eta0': 0.1, 'l1_ratio': 0.6, 'learning_rate': 'invscaling', 'penalty': 'l2'}
# 1.048769173247169 {'alpha': 0.1, 'early_stopping': True, 'eta0': 0.1, 'l1_ratio': 0.6, 'learning_rate': 'invscaling', 'penalty': 'l1'}
# 1.020495426939023 {'alpha': 0.1, 'early_stopping': True, 'eta0': 0.1, 'l1_ratio': 0.6, 'learning_rate': 'invscaling', 'penalty': 'elasticnet'}
# 1.2658840431768124 {'alpha': 0.1, 'early_stopping': True, 'eta0': 0.1, 'l1_ratio': 0.6, 'learning_rate': 'adaptive', 'penalty': 'l2'}
# 1.0346052130057246 {'alpha': 0.1, 'early_stopping': True, 'eta0': 0.1, 'l1_ratio': 0.6, 'learning_rate': 'adaptive', 'penalty': 'l1'}
# 1.0511942981637359 {'alpha': 0.1, 'early_stopping': True, 'eta0': 0.1, 'l1_ratio': 0.6, 'learning_rate': 'adaptive', 'penalty': 'elasticnet'}
# 12.35383808682853 {'alpha': 0.1, 'early_stopping': True, 'eta0': 0.1, 'l1_ratio': 0.8, 'learning_rate': 'constant', 'penalty': 'l2'}
# 1.031690999400586 {'alpha': 0.1, 'early_stopping': True, 'eta0': 0.1, 'l1_ratio': 0.8, 'learning_rate': 'constant', 'penalty': 'l1'}
# 1.0406463647038837 {'alpha': 0.1, 'early_stopping': True, 'eta0': 0.1, 'l1_ratio': 0.8, 'learning_rate': 'constant', 'penalty': 'elasticnet'}
# 4155850.870851457 {'alpha': 0.1, 'early_stopping': True, 'eta0': 0.1, 'l1_ratio': 0.8, 'learning_rate': 'optimal', 'penalty': 'l2'}
# 99410241.85756873 {'alpha': 0.1, 'early_stopping': True, 'eta0': 0.1, 'l1_ratio': 0.8, 'learning_rate': 'optimal', 'penalty': 'l1'}
# 1189344657.0755565 {'alpha': 0.1, 'early_stopping': True, 'eta0': 0.1, 'l1_ratio': 0.8, 'learning_rate': 'optimal', 'penalty': 'elasticnet'}
# 1.0633371422882927 {'alpha': 0.1, 'early_stopping': True, 'eta0': 0.1, 'l1_ratio': 0.8, 'learning_rate': 'invscaling', 'penalty': 'l2'}
# 1.0489009637753153 {'alpha': 0.1, 'early_stopping': True, 'eta0': 0.1, 'l1_ratio': 0.8, 'learning_rate': 'invscaling', 'penalty': 'l1'}
# 1.0259599896142122 {'alpha': 0.1, 'early_stopping': True, 'eta0': 0.1, 'l1_ratio': 0.8, 'learning_rate': 'invscaling', 'penalty': 'elasticnet'}
# 1.0584624408208791 {'alpha': 0.1, 'early_stopping': True, 'eta0': 0.1, 'l1_ratio': 0.8, 'learning_rate': 'adaptive', 'penalty': 'l2'}
# 1.0225644633163582 {'alpha': 0.1, 'early_stopping': True, 'eta0': 0.1, 'l1_ratio': 0.8, 'learning_rate': 'adaptive', 'penalty': 'l1'}
# 1.0529749456152349 {'alpha': 0.1, 'early_stopping': True, 'eta0': 0.1, 'l1_ratio': 0.8, 'learning_rate': 'adaptive', 'penalty': 'elasticnet'}

# %%
ys_sgd_final_model = grid_search.best_estimator_

# %%
ys_sgd_train_predictions = ys_sgd_final_model.predict(X_train_std) * np.std(ys_train) + np.mean(ys_train)
ys_sgd_train_mse = mean_squared_error(ys_train, ys_sgd_train_predictions)
ys_sgd_train_rmse = np.sqrt(ys_sgd_train_mse)
ys_sgd_train_rmse
# Out:
# 59.420206382358465

# %%
ys_train
# Out:
# array([[376.9174364],
#        [239.0132519],
#        [254.2909124],
#        [396.6477999],
#        [366.654355 ],
#        [318.7140645],
#        [314.1545951],
#        [378.8268752],
#        [302.5575995],
#        [311.728646 ],
#        [346.6789108],
#        [319.843856 ],
#        [393.9139928],
#        [397.7503173],
#        [361.6173138],
#        [322.0143481],
#        [392.1883937],
#        [374.8920937],
#        [298.3380418],
#        [230.2185847],
#        [293.8730246],
#        [249.4376223],
#        [343.2400466],
#        [360.1355076],
#        [198.0040467],
#        [367.4049917],
#        [349.1988703],
#        [376.219849 ],
#        [303.9293331],
#        [380.7116965],
#        [316.4556836],
#        [374.2402416],
#        [331.2731424],
#        [387.5319199],
#        [287.5707808],
#        [246.945844 ],
#        [368.7684819],
#        [347.4849133],
#        [340.591275 ],
#        [320.9614608],
#        [390.4515104],
#        [290.7865768],
#        [354.0550831],
#        [263.2457198],
#        [193.928416 ],
#        [241.7331269],
#        [277.1383167],
#        [352.3927397],
#        [334.1010653],
#        [193.928416 ],
#        [337.8421387],
#        [392.7784793],
#        [360.8944233],
#        [395.5306474],
#        [393.3242347],
#        [295.3877316],
#        [256.5907645],
#        [278.9672283],
#        [406.3508414],
#        [310.4938396],
#        [355.5446436],
#        [372.2525223],
#        [405.929592 ],
#        [404.9486537],
#        [373.60206  ],
#        [371.5047515],
#        [353.2571561],
#        [244.3682141],
#        [305.2761365],
#        [378.1495705],
#        [324.1410847],
#        [388.0935933],
#        [381.9959288],
#        [193.928416 ],
#        [386.8933627],
#        [350.7724668],
#        [220.5943573],
#        [299.7695692],
#        [265.3309169],
#        [202.0658311],
#        [383.2324675],
#        [351.607539 ],
#        [370.1830482],
#        [377.5188987],
#        [269.4774137],
#        [307.9326591],
#        [402.4621999],
#        [323.0917671],
#        [296.871402 ],
#        [348.3210261],
#        [205.9914438],
#        [396.0356226],
#        [284.2355762],
#        [315.3368533],
#        [227.1339494],
#        [400.3926709],
#        [385.6841251],
#        [301.1719203],
#        [368.0616517],
#        [405.4081423],
#        [357.9091233],
#        [363.0492358],
#        [345.859194 ],
#        [389.2722846],
#        [306.5893409],
#        [401.9368673],
#        [398.2770909],
#        [325.1762356],
#        [339.6660743],
#        [289.1981942],
#        [193.928416 ],
#        [312.9690544],
#        [381.3615336],
#        [362.3813123],
#        [335.9624187],
#        [370.8627499],
#        [399.8787968],
#        [258.9109635],
#        [193.928416 ],
#        [403.9912956],
#        [406.8904463],
#        [403.4151475],
#        [356.3153804],
#        [327.2465236],
#        [251.9092047],
#        [273.3904667],
#        [394.964976 ],
#        [275.2899157],
#        [317.6245466],
#        [213.5049508],
#        [344.9516204],
#        [341.4414326],
#        [388.668949 ],
#        [372.9182268],
#        [394.4477481],
#        [236.144673 ],
#        [363.8093514],
#        [280.763122 ],
#        [209.7944582],
#        [285.8931189],
#        [309.2107175],
#        [364.5557704],
#        [391.5849102],
#        [359.4348317],
#        [404.4287558],
#        [383.8712795],
#        [400.8878322],
#        [380.087891 ],
#        [398.8200636],
#        [344.08029  ],
#        [399.2994626],
#        [385.0915993]])

# %%
ys_sgd_train_predictions
# Out:
# array([332.2373685 , 332.63367389, 332.15883666, 332.4550042 ,
#        332.51120646, 332.48172153, 332.4346786 , 332.23220812,
#        332.5547797 , 332.57574546, 332.68078308, 332.46657721,
#        332.53735826, 332.11916962, 332.17432986, 332.07212688,
#        332.63783197, 332.14348935, 332.26459546, 332.68403755,
#        332.4460932 , 332.61780504, 332.4848841 , 332.67245014,
#        332.11051972, 332.56237977, 332.51746056, 332.66111861,
#        332.09876971, 332.62849927, 332.28923605, 332.43817723,
#        332.21320815, 332.5030641 , 332.4988783 , 332.11024372,
#        332.21593392, 332.25033045, 332.18961293, 332.60290715,
#        332.6542536 , 332.23200253, 332.46776438, 332.64071348,
#        332.13163428, 332.02775173, 332.15177323, 332.48012294,
#        332.68284119, 332.12294358, 332.63358311, 332.21159738,
#        332.49278811, 332.41048063, 332.57392816, 332.70739604,
#        332.13247951, 332.28131712, 332.50839269, 332.18047529,
#        332.25468389, 332.60969226, 332.72996625, 332.12030612,
#        332.63403503, 332.74385456, 332.53946258, 332.43350579,
#        332.45799288, 332.3056622 , 332.19962412, 332.64988108,
#        332.60405467, 332.36248757, 332.41906101, 332.29254366,
#        332.66658917, 332.23050483, 332.44958342, 332.66790028,
#        332.20448101, 332.35329913, 332.57965016, 332.11721137,
#        332.05388274, 332.63596591, 332.61545481, 332.43186664,
#        332.16037977, 332.43509539, 332.5865114 , 332.56538752,
#        332.67874937, 332.17708443, 332.51678328, 332.53730153,
#        332.52730901, 332.3357249 , 332.49505329, 332.6834158 ,
#        332.59060439, 332.44514057, 332.13064163, 332.27011763,
#        332.52234011, 332.28042302, 332.68263001, 332.54821742,
#        332.64630186, 332.33424866, 332.72606657, 332.21023074,
#        332.55518379, 332.61026385, 332.21192275, 332.67734642,
#        332.27124059, 332.53175056, 332.53464059, 332.41411222,
#        332.13687351, 332.53115905, 332.63632746, 332.15380565,
#        332.28676179, 332.55793276, 332.60140097, 332.68566681,
#        332.43674208, 332.66112519, 332.65198236, 332.50961087,
#        332.49003069, 332.20937046, 332.23727636, 332.43649035,
#        332.1046693 , 332.19297032, 332.63665493, 332.32518462,
#        332.74025756, 332.52781388, 332.49629544, 332.07073245,
#        332.31073591, 332.14372957, 332.31513967, 332.65965096,
#        332.47800754, 332.65709834, 332.55531804, 332.68272321])

# %%
ys_sgd_test_predictions = ys_sgd_final_model.predict(X_test_std)  * np.std(ys_test) + np.mean(ys_test)
ys_sgd_test_mse = mean_squared_error(ys_test,ys_sgd_test_predictions)
ys_sgd_test_rmse = np.sqrt(ys_sgd_test_mse)
ys_sgd_test_rmse
# Out:
# 62.167378770348655

# %% [markdown]
# ## Central Limit Theorem

# %%
print(cvres['mean_train_score'].shape)
print('Combinations')

# %%
mean_train_score = cvres['mean_train_score']
print(mean_train_score)

# %%
mean_test_score = cvres['mean_test_score']
print(mean_test_score)

# %%
std_train_score = cvres['std_train_score']
print(std_test_score)

# %%
std_test_score = cvres['std_test_score']
print(std_test_score)

# %%
#with open('/content/gdrive/My Drive/validation/cvscores/SGD/yield_stress/SGD_2V.txt', 'w') as f:
with open('/BestHyperParameter/SGD_Regression/yield_stress_2V/SGD_2V.txt', 'w') as f: 
  for key in cvres.keys():
    f.write("\n")
    f.write(key)
    f.write(": ")
    f.write(np.str(cvres[key]))
    f.write("\n")
    


# !cat /content/gdrive/My Drive/validation/cvscores/SGD/yield_stress/SGD_2V.txt

# %% [markdown]
# ## Train data plotting

# %%
# Difference of train data
xx = np.linspace(0,len(X_train),len(X_train))
plt.figure
plt.grid()
ys_train_sort = np.sort(ys_train, axis=None)
ys_sgd_train_predictions_sort= np.sort(ys_sgd_train_predictions, axis=None)
plt.plot(xx,ys_train_sort,"b-", xx, ys_sgd_train_predictions_sort,"r--")
plt.title("Train data vs Train Prediction(SGD) Param Fitted")
plt.xlabel("Order of data")
plt.ylabel("Yield Stress")
save_fig("TrainPrediction_with_2V_SGD_ParamFitted")
# Out:
# Saving figure Train data vs Train Prediction with 2 variables SGD Param Fitted

# %%
# Difference of train data
difference = ys_train_sort - ys_sgd_train_predictions_sort

xx = np.linspace(0,len(difference),len(difference))
y = np.zeros((len(difference),1))
#y.reshape(1,len(difference))
plt.figure
plt.grid()
plt.plot(xx,y,"b-", xx, difference,"r--")
plt.title("Difference between Train data vs Prediction(SGD) Param Fitted")
#plt.ylim(-30, 30)
plt.xlabel("Order of data")
plt.ylabel("Yield Stress")

save_fig("Difference_between_Train_data_vs_Prediction_2V_SGD_ParamFitted")
# Out:
# Saving figure Difference between Train data vs Prediction  2 variables SGD Param Fitted

# %% [markdown]
# ## Test data plotting

# %%
# Difference of test data
xx = np.linspace(0,len(X_test),len(X_test))
plt.figure
plt.grid()
ys_test_sort = np.sort(ys_test, axis=None)
ys_sgd_test_predictions_sort= np.sort(ys_sgd_test_predictions, axis=None)
plt.plot(xx,ys_test_sort,"b-", xx, ys_sgd_test_predictions_sort,"r--")
plt.title("Test data vs Test Prediction(SGD) Param Fitted")
plt.xlabel("Order of data")
plt.ylabel("Yield Stress")
save_fig("TestPrediction_with_2V_SGD_ParamFitted")
# Out:
# Saving figure Test data vs Test Prediction with 2 variables SGD Param Fitted

# %%
# Difference of test data
difference = ys_test_sort - ys_sgd_test_predictions_sort

xx = np.linspace(0,len(difference),len(difference))
y = np.zeros((len(difference),1))
#y.reshape(1,len(difference))
plt.figure
plt.grid()
plt.plot(xx,y,"b-", xx, difference,"r--")
plt.title("Difference between Test data vs Prediction(SGD) Param Fitted")
#plt.ylim(-30, 30)
plt.xlabel("Order of data")
plt.ylabel("Yield Stress")

save_fig("Difference_between_Test_data_vs_Prediction_2V_SGD_ParamFitted")
# Out:
# Saving figure Difference between Test data vs Prediction  2 variables SGD Param Fitted

# %% [markdown]
# ## Extracting files

# %%
from google.colab import files
# Upload local files to Colab VM
#uploaded = files.upload()
# Download Colab VM fiels to local
files.download('images/BestHyperParameter/SGD_Regression/yield_stress_2V/TrainPrediction_with_2V_SGD_ParamFitted.png')

# %%
files.download('images/BestHyperParameter/SGD_Regression/yield_stress_2V/TestPrediction_with_2V_SGD_ParamFitted.png')

# %%
files.download('images/BestHyperParameter/SGD_Regression/yield_stress_2V/Difference_between_Train_data_vs_Prediction_2V_SGD_ParamFitted.png')

# %%
files.download('images/BestHyperParameter/SGD_Regression/yield_stress_2V/Difference_between_Test_data_vs_Prediction_2V_SGD_ParamFitted.png')

# %%
files.download('/content/gdrive/My Drive/validation/cvscores/SGD/SGD_2V.txt')

# %% [markdown]
# #### elongation
